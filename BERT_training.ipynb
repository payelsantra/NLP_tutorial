# %% [markdown]
# # Project Outline
# - Step 1: Introduction (this section)
#
# - Step 2: Exploratory Data Analysis and Preprocessing
#
# - Step 3: Without Finetuning
#
# - Step 4: Loading Tokenizer and Encoding our Data
#
# - Step 5: Setting up BERT Pretrained Model
#
# - Step 6: Creating Data Loaders
#
# - Step 7: Setting Up Optimizer and Scheduler
#
# - Step 8: Defining our Performance Metrics
#
# - Step 9: Finetune BERT and SciBERT

# %% [markdown]
# ## Introduction

# %% [markdown]
# [BERT](https://https://huggingface.co/docs/transformers/model_doc/bert) is a large-scale transformer-based Language Model that can be finetuned for a variety of tasks. For more information, the original paper can be found [here](https://https://arxiv.org/abs/1810.04805).
#
# [SciBERT](https://huggingface.co/allenai/scibert_scivocab_uncased) is BERT trained on scientific text. For more information, the original paper can be found [here](https://aclanthology.org/D19-1371/).

# %% [markdown]
# ## Exploratory Data Analysis and Preprocessing

# %%
from datasets import load_dataset
import pandas as pd
import torch
from tqdm import tqdm

sst2 = load_dataset("stanfordnlp/sst2")
sst2
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/3.11M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/72.8k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/148k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/872 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 67349
#     })
#     validation: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 872
#     })
#     test: Dataset({
#         features: ['idx', 'sentence', 'label'],
#         num_rows: 1821
#     })
# })

# %%
# Build dataframes
df_train = pd.DataFrame(sst2["train"])
df_val   = pd.DataFrame(sst2["validation"])

# %%
print(df_train.head(10).to_markdown(index=False)) # 10 examples are demonstrated here
# Out:
# |   idx | sentence                                                                                                                                             |   label |
# |------:|:-----------------------------------------------------------------------------------------------------------------------------------------------------|--------:|
# |     0 | hide new secretions from the parental units                                                                                                          |       0 |
# |     1 | contains no wit , only labored gags                                                                                                                  |       0 |
# |     2 | that loves its characters and communicates something rather beautiful about human nature                                                             |       1 |
# |     3 | remains utterly satisfied to remain the same throughout                                                                                              |       0 |
# |     4 | on the worst revenge-of-the-nerds clichés the filmmakers could dredge up                                                                             |       0 |
# |     5 | that 's far too tragic to merit such superficial treatment                                                                                           |       0 |
# |     6 | demonstrates that the director of such hollywood blockbusters as patriot games can still turn out a small , personal film with an emotional wallop . |       1 |
# |     7 | of saucy                                                                                                                                             |       1 |
# |     8 | a depressed fifteen-year-old 's suicidal poetry                                                                                                      |       0 |
# |     9 | are more deeply thought through than in most ` right-thinking ' films                                                                                |       1 |

# %%
split_idx = int(0.8 * len(df_val))

df_train_small = df_val.iloc[:split_idx].reset_index(drop=True)
df_val_small  = df_val.iloc[split_idx:].reset_index(drop=True)

print("Train:", len(df_train_small))
print("Test :", len(df_val_small))
# Out:
# Train: 697
# Test : 175

# %%
df_train_small.label.value_counts()
#Point to be noted, you have to convert the categorical labels into numerical labels, if exists. like, positive --> 1, Negative --> 0.
# Out:
# label
# 1    357
# 0    340
# Name: count, dtype: int64

# %%
possible_labels = df_train_small.label.unique()
print("possible_labels",possible_labels)
# Out:
# possible_labels [1 0]

# %%
#Optional for categorical to numerical map
label_dict = {}
for index, possible_label in enumerate(possible_labels):
    label_dict[possible_label] = index

# %%
label_dict #{"Positive":1, "Negative":0}
# Out:
# {np.int64(1): 0, np.int64(0): 1}

# %%
label_dict_inverse = {1: "Positive", 0:"Negative"}

# %% [markdown]
# ## without finetuning BERT

# %%
from transformers import AutoTokenizer, AutoModel
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
bert = AutoModel.from_pretrained("bert-base-uncased")

bert.to(device)
bert.eval()   #notice
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def get_bert_cls_embeddings(sentences, batch_size=32, max_len=128):

    all_embeddings = []

    with torch.no_grad():
        for i in tqdm(range(0, len(sentences), batch_size)):

            batch = sentences[i:i+batch_size]

            enc = tokenizer(
                batch,
                padding=True,
                truncation=True,
                max_length=max_len,
                return_tensors="pt"
            )

            enc = {k: v.to(device) for k, v in enc.items()}

            outputs = bert(**enc)

            # CLS token representation
            cls_emb = outputs.last_hidden_state[:, 0, :]  # (B, 768)

            all_embeddings.append(cls_emb.cpu())

    return torch.cat(all_embeddings, dim=0)

# %%
X_train = get_bert_cls_embeddings(
    df_train_small["sentence"].tolist()
)

X_val = get_bert_cls_embeddings(
    df_val_small["sentence"].tolist()
)

y_train = df_train_small["label"].values
y_val   = df_val_small["label"].values

print(X_train.shape, X_val.shape)
# Out:
# 100%|██████████| 22/22 [00:00<00:00, 26.82it/s]
# 100%|██████████| 6/6 [00:00<00:00, 27.56it/s]
# torch.Size([697, 768]) torch.Size([175, 768])

# %%
import torch.nn as nn
#768  →  256  →  1

class MLPClassifier(nn.Module):
    def __init__(self, in_dim, hidden_dim=256):
        super().__init__()

        self.fc1 = nn.Linear(in_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x.squeeze(-1)

# %%
model = MLPClassifier(768,256).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
Xtr = X_train.to(device)
ytr = torch.tensor(y_train, dtype=torch.float32).to(device)

for epoch in range(10):
    model.train()

    optimizer.zero_grad()
    logits = model(Xtr)

    loss = criterion(logits, ytr)
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch} loss: {loss.item():.4f}")
# Out:
# Epoch 0 loss: 0.6967
# Epoch 1 loss: 0.6585
# Epoch 2 loss: 0.6238
# Epoch 3 loss: 0.5899
# Epoch 4 loss: 0.5567
# Epoch 5 loss: 0.5252
# Epoch 6 loss: 0.4960
# Epoch 7 loss: 0.4691
# Epoch 8 loss: 0.4445
# Epoch 9 loss: 0.4221

# %%
model.eval()
with torch.no_grad():
    logits = model(X_val.to(device))
    probs = torch.sigmoid(logits)
    preds = (probs > 0.5).long().cpu().numpy()

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report

print("Accuracy:", accuracy_score(y_val, preds))
print("F1:", f1_score(y_val, preds))
print(classification_report(
        y_val, preds
    ))
# Out:
# Accuracy: 0.7828571428571428
# F1: 0.7934782608695652
#               precision    recall  f1-score   support
#
#            0       0.82      0.73      0.77        88
#            1       0.75      0.84      0.79        87
#
#     accuracy                           0.78       175
#    macro avg       0.79      0.78      0.78       175
# weighted avg       0.79      0.78      0.78       175

# %% [markdown]
# ## without finetuning SciBERT

# %%
from transformers import AutoTokenizer, AutoModel
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

tokenizer = AutoTokenizer.from_pretrained("allenai/scibert_scivocab_uncased")
bert = AutoModel.from_pretrained("allenai/scibert_scivocab_uncased")

bert.to(device)
bert.eval()   #notice
# Out:
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: allenai/scibert_scivocab_uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(31090, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def get_bert_cls_embeddings(sentences, batch_size=32, max_len=128):

    all_embeddings = []

    with torch.no_grad():
        for i in tqdm(range(0, len(sentences), batch_size)):

            batch = sentences[i:i+batch_size]

            enc = tokenizer(
                batch,
                padding=True,
                truncation=True,
                max_length=max_len,
                return_tensors="pt"
            )

            enc = {k: v.to(device) for k, v in enc.items()}

            outputs = bert(**enc)

            # CLS token representation
            cls_emb = outputs.last_hidden_state[:, 0, :]  # (B, 768)

            all_embeddings.append(cls_emb.cpu())

    return torch.cat(all_embeddings, dim=0)

# %%
X_train = get_bert_cls_embeddings(
    df_train_small["sentence"].tolist()
)

X_val = get_bert_cls_embeddings(
    df_val_small["sentence"].tolist()
)

y_train = df_train_small["label"].values
y_val   = df_val_small["label"].values

print(X_train.shape, X_val.shape)
# Out:
# 100%|██████████| 22/22 [00:00<00:00, 27.18it/s]
# 100%|██████████| 6/6 [00:00<00:00, 29.46it/s]
# torch.Size([697, 768]) torch.Size([175, 768])

# %%
import torch.nn as nn
#768  →  256  →  1

class MLPClassifier(nn.Module):
    def __init__(self, in_dim, hidden_dim=256):
        super().__init__()

        self.fc1 = nn.Linear(in_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x.squeeze(-1)

# %%
model = MLPClassifier(768,256).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
Xtr = X_train.to(device)
ytr = torch.tensor(y_train, dtype=torch.float32).to(device)

for epoch in range(10):
    model.train()

    optimizer.zero_grad()
    logits = model(Xtr)

    loss = criterion(logits, ytr)
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch} loss: {loss.item():.4f}")
# Out:
# Epoch 0 loss: 0.6945
# Epoch 1 loss: 0.6807
# Epoch 2 loss: 0.6277
# Epoch 3 loss: 0.6232
# Epoch 4 loss: 0.5815
# Epoch 5 loss: 0.5700
# Epoch 6 loss: 0.5557
# Epoch 7 loss: 0.5302
# Epoch 8 loss: 0.5236
# Epoch 9 loss: 0.5110

# %%
model.eval()
with torch.no_grad():
    logits = model(X_val.to(device))
    probs = torch.sigmoid(logits)
    preds = (probs > 0.5).long().cpu().numpy()

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report

print("Accuracy:", accuracy_score(y_val, preds))
print("F1:", f1_score(y_val, preds))
print(classification_report(
        y_val, preds
    ))
# Out:
# Accuracy: 0.72
# F1: 0.7262569832402235
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71        88
#            1       0.71      0.75      0.73        87
#
#     accuracy                           0.72       175
#    macro avg       0.72      0.72      0.72       175
# weighted avg       0.72      0.72      0.72       175

# %% [markdown]
# ## Loading Tokenizer and Encoding our Data

# %%
from transformers import AutoTokenizer
from torch.utils.data import TensorDataset
import torch

# %%
# Initialise tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased",do_lower_case=True)

# %%
# -------- train split --------
encoded_data_train = tokenizer(
    df_train_small["sentence"].values.tolist(),
    add_special_tokens=True,
    return_attention_mask=True,
    pad_to_max_length=True,
    max_length=256,
    return_tensors='pt',padding=True,truncation=True
)

input_ids_train = encoded_data_train["input_ids"]
attention_masks_train = encoded_data_train["attention_mask"]
labels_train = torch.tensor(df_train_small["label"].values)


# -------- validation split --------
encoded_data_val = tokenizer(
    df_val_small["sentence"].values.tolist(),
    add_special_tokens=True,
    return_attention_mask=True,
    pad_to_max_length=True,
    max_length=256,
    return_tensors='pt',padding=True,truncation=True
)

input_ids_val = encoded_data_val["input_ids"]
attention_masks_val = encoded_data_val["attention_mask"]
labels_val = torch.tensor(df_val_small["label"].values)

# %%
# -------- TensorDataset (same style as your codebase) --------
dataset_train = TensorDataset(
    input_ids_train,
    attention_masks_train,
    labels_train
)

dataset_val = TensorDataset(
    input_ids_val,
    attention_masks_val,
    labels_val
)

# %%
print(len(dataset_train))

print(len(dataset_val))
# Out:
# 697
# 175

# %% [markdown]
# ## Setting up BERT Pretrained Model

# %%
from transformers import BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %% [markdown]
# ### Creating Data Loaders

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
batch_size = 8

dataloader_train = DataLoader(dataset_train,
                              sampler=RandomSampler(dataset_train),
                              batch_size=batch_size)

dataloader_validation = DataLoader(dataset_val,
                                   sampler=SequentialSampler(dataset_val),
                                   batch_size=batch_size)

# %% [markdown]
# ## Setting Up Optimiser and Scheduler

# %%
from torch.optim import AdamW
from transformers import get_linear_schedule_with_warmup

# %%
# Optimizer
optimizer = AdamW(model.parameters(), lr=2e-5)

# %%
epochs = 10

scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps=0,
                                            num_training_steps=len(dataloader_train)*epochs)

# %% [markdown]
# ## Defining our Performance Metrics

# %%
import numpy as np
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    f1_score,
    confusion_matrix
)

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

# %%
def accuracy_per_class(preds, labels):
    label_dict_inverse = {v: k for k, v in label_dict.items()}

    preds_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()

    print("\nClassification report:")
    print(classification_report(
        labels_flat,
        preds_flat
    ))

    overall_acc = accuracy_score(labels_flat, preds_flat)

    f1_macro    = f1_score(labels_flat, preds_flat, average="macro")

    print("Overall accuracy:", overall_acc)
    print("F1 macro       :", f1_macro)

    # for label in np.unique(labels_flat):
    #     y_preds = preds_flat[labels_flat==label]
    #     y_true = labels_flat[labels_flat==label]
    #     print(f'Class: {label_dict_inverse[label]}')
    #     print(f'Accuracy: {len(y_preds[y_preds==label])}/{len(y_true)}\n')

# %% [markdown]
# ## Finetuning BERT

# %%
import random

seed_val = 0
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()

    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total/len(dataloader_val)

    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):

    model.train()

    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        outputs = model(**inputs)

        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()

        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})


    torch.save(model.state_dict(), f'finetuned_BERT_epoch_{epoch}.model')

    tqdm.write(f'\nEpoch {epoch}')

    loss_train_avg = loss_train_total/len(dataloader_train)
    tqdm.write(f'Training loss: {loss_train_avg}')

    # val_loss, predictions, true_vals = evaluate(dataloader_validation)
    # val_f1 = f1_score_func(predictions, true_vals)
    # tqdm.write(f'Validation loss: {val_loss}')
    # tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.247]
# Epoch 1:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.214]
# Epoch 1:   2%|▏         | 2/88 [00:00<00:06, 12.59it/s, training_loss=0.214]
# Epoch 1:   2%|▏         | 2/88 [00:00<00:06, 12.59it/s, training_loss=0.228]
# Epoch 1:   2%|▏         | 2/88 [00:00<00:06, 12.59it/s, training_loss=0.226]
# Epoch 1:   5%|▍         | 4/88 [00:00<00:06, 12.80it/s, training_loss=0.226]
# Epoch 1:   5%|▍         | 4/88 [00:00<00:06, 12.80it/s, training_loss=0.202]
# Epoch 1:   5%|▍         | 4/88 [00:00<00:06, 12.80it/s, training_loss=0.260]
# Epoch 1:   7%|▋         | 6/88 [00:00<00:06, 12.83it/s, training_loss=0.260]
# Epoch 1:   7%|▋         | 6/88 [00:00<00:06, 12.83it/s, training_loss=0.229]
# Epoch 1:   7%|▋         | 6/88 [00:00<00:06, 12.83it/s, training_loss=0.238]
# Epoch 1:   9%|▉         | 8/88 [00:00<00:06, 12.85it/s, training_loss=0.238]
# Epoch 1:   9%|▉         | 8/88 [00:00<00:06, 12.85it/s, training_loss=0.232]
# Epoch 1:   9%|▉         | 8/88 [00:00<00:06, 12.85it/s, training_loss=0.200]
# Epoch 1:  11%|█▏        | 10/88 [00:00<00:06, 12.86it/s, training_loss=0.200]
# Epoch 1:  11%|█▏        | 10/88 [00:00<00:06, 12.86it/s, training_loss=0.214]
# Epoch 1:  11%|█▏        | 10/88 [00:00<00:06, 12.86it/s, training_loss=0.188]
# Epoch 1:  14%|█▎        | 12/88 [00:00<00:05, 12.88it/s, training_loss=0.188]
# Epoch 1:  14%|█▎        | 12/88 [00:01<00:05, 12.88it/s, training_loss=0.185]
# Epoch 1:  14%|█▎        | 12/88 [00:01<00:05, 12.88it/s, training_loss=0.257]
# Epoch 1:  16%|█▌        | 14/88 [00:01<00:05, 12.84it/s, training_loss=0.257]
# Epoch 1:  16%|█▌        | 14/88 [00:01<00:05, 12.84it/s, training_loss=0.184]
# Epoch 1:  16%|█▌        | 14/88 [00:01<00:05, 12.84it/s, training_loss=0.224]
# Epoch 1:  18%|█▊        | 16/88 [00:01<00:05, 12.85it/s, training_loss=0.224]
# Epoch 1:  18%|█▊        | 16/88 [00:01<00:05, 12.85it/s, training_loss=0.222]
# Epoch 1:  18%|█▊        | 16/88 [00:01<00:05, 12.85it/s, training_loss=0.228]
# Epoch 1:  20%|██        | 18/88 [00:01<00:05, 12.83it/s, training_loss=0.228]
# Epoch 1:  20%|██        | 18/88 [00:01<00:05, 12.83it/s, training_loss=0.236]
# Epoch 1:  20%|██        | 18/88 [00:01<00:05, 12.83it/s, training_loss=0.199]
# Epoch 1:  23%|██▎       | 20/88 [00:01<00:05, 12.84it/s, training_loss=0.199]
# Epoch 1:  23%|██▎       | 20/88 [00:01<00:05, 12.84it/s, training_loss=0.226]
# Epoch 1:  23%|██▎       | 20/88 [00:01<00:05, 12.84it/s, training_loss=0.242]
# Epoch 1:  25%|██▌       | 22/88 [00:01<00:05, 12.85it/s, training_loss=0.242]
# Epoch 1:  25%|██▌       | 22/88 [00:01<00:05, 12.85it/s, training_loss=0.205]
# Epoch 1:  25%|██▌       | 22/88 [00:01<00:05, 12.85it/s, training_loss=0.159]
# Epoch 1:  27%|██▋       | 24/88 [00:01<00:04, 12.81it/s, training_loss=0.159]
# Epoch 1:  27%|██▋       | 24/88 [00:01<00:04, 12.81it/s, training_loss=0.171]
# Epoch 1:  27%|██▋       | 24/88 [00:02<00:04, 12.81it/s, training_loss=0.176]
# Epoch 1:  30%|██▉       | 26/88 [00:02<00:04, 12.83it/s, training_loss=0.176]
# Epoch 1:  30%|██▉       | 26/88 [00:02<00:04, 12.83it/s, training_loss=0.188]
# Epoch 1:  30%|██▉       | 26/88 [00:02<00:04, 12.83it/s, training_loss=0.195]
# Epoch 1:  32%|███▏      | 28/88 [00:02<00:04, 12.81it/s, training_loss=0.195]
# Epoch 1:  32%|███▏      | 28/88 [00:02<00:04, 12.81it/s, training_loss=0.212]
# Epoch 1:  32%|███▏      | 28/88 [00:02<00:04, 12.81it/s, training_loss=0.209]
# Epoch 1:  34%|███▍      | 30/88 [00:02<00:04, 12.84it/s, training_loss=0.209]
# Epoch 1:  34%|███▍      | 30/88 [00:02<00:04, 12.84it/s, training_loss=0.241]
# Epoch 1:  34%|███▍      | 30/88 [00:02<00:04, 12.84it/s, training_loss=0.172]
# Epoch 1:  36%|███▋      | 32/88 [00:02<00:04, 12.87it/s, training_loss=0.172]
# Epoch 1:  36%|███▋      | 32/88 [00:02<00:04, 12.87it/s, training_loss=0.202]
# Epoch 1:  36%|███▋      | 32/88 [00:02<00:04, 12.87it/s, training_loss=0.189]
# Epoch 1:  39%|███▊      | 34/88 [00:02<00:04, 12.86it/s, training_loss=0.189]
# Epoch 1:  39%|███▊      | 34/88 [00:02<00:04, 12.86it/s, training_loss=0.151]
# Epoch 1:  39%|███▊      | 34/88 [00:02<00:04, 12.86it/s, training_loss=0.182]
# Epoch 1:  41%|████      | 36/88 [00:02<00:04, 12.84it/s, training_loss=0.182]
# Epoch 1:  41%|████      | 36/88 [00:02<00:04, 12.84it/s, training_loss=0.147]
# Epoch 1:  41%|████      | 36/88 [00:02<00:04, 12.84it/s, training_loss=0.155]
# Epoch 1:  43%|████▎     | 38/88 [00:02<00:03, 12.86it/s, training_loss=0.155]
# Epoch 1:  43%|████▎     | 38/88 [00:03<00:03, 12.86it/s, training_loss=0.124]
# Epoch 1:  43%|████▎     | 38/88 [00:03<00:03, 12.86it/s, training_loss=0.174]
# Epoch 1:  45%|████▌     | 40/88 [00:03<00:03, 12.87it/s, training_loss=0.174]
# Epoch 1:  45%|████▌     | 40/88 [00:03<00:03, 12.87it/s, training_loss=0.216]
# Epoch 1:  45%|████▌     | 40/88 [00:03<00:03, 12.87it/s, training_loss=0.157]
# Epoch 1:  48%|████▊     | 42/88 [00:03<00:03, 12.82it/s, training_loss=0.157]
# Epoch 1:  48%|████▊     | 42/88 [00:03<00:03, 12.82it/s, training_loss=0.131]
# Epoch 1:  48%|████▊     | 42/88 [00:03<00:03, 12.82it/s, training_loss=0.105]
# Epoch 1:  50%|█████     | 44/88 [00:03<00:03, 12.77it/s, training_loss=0.105]
# Epoch 1:  50%|█████     | 44/88 [00:03<00:03, 12.77it/s, training_loss=0.142]
# Epoch 1:  50%|█████     | 44/88 [00:03<00:03, 12.77it/s, training_loss=0.190]
# Epoch 1:  52%|█████▏    | 46/88 [00:03<00:03, 12.75it/s, training_loss=0.190]
# Epoch 1:  52%|█████▏    | 46/88 [00:03<00:03, 12.75it/s, training_loss=0.098]
# Epoch 1:  52%|█████▏    | 46/88 [00:03<00:03, 12.75it/s, training_loss=0.108]
# Epoch 1:  55%|█████▍    | 48/88 [00:03<00:03, 12.71it/s, training_loss=0.108]
# Epoch 1:  55%|█████▍    | 48/88 [00:03<00:03, 12.71it/s, training_loss=0.075]
# Epoch 1:  55%|█████▍    | 48/88 [00:03<00:03, 12.71it/s, training_loss=0.103]
# Epoch 1:  57%|█████▋    | 50/88 [00:03<00:02, 12.68it/s, training_loss=0.103]
# Epoch 1:  57%|█████▋    | 50/88 [00:03<00:02, 12.68it/s, training_loss=0.059]
# Epoch 1:  57%|█████▋    | 50/88 [00:04<00:02, 12.68it/s, training_loss=0.052]
# Epoch 1:  59%|█████▉    | 52/88 [00:04<00:02, 12.59it/s, training_loss=0.052]
# Epoch 1:  82%|████████▏ | 72/88 [00:05<00:01, 12.56it/s, training_loss=0.467]
# Epoch 1:  82%|████████▏ | 72/88 [00:05<00:01, 12.56it/s, training_loss=0.246]
# Epoch 1:  84%|████████▍ | 74/88 [00:05<00:01, 12.52it/s, training_loss=0.246]
# Epoch 1:  84%|████████▍ | 74/88 [00:05<00:01, 12.52it/s, training_loss=0.066]
# Epoch 1:  84%|████████▍ | 74/88 [00:05<00:01, 12.52it/s, training_loss=0.132]
# Epoch 1:  86%|████████▋ | 76/88 [00:05<00:00, 12.57it/s, training_loss=0.132]
# Epoch 1:  86%|████████▋ | 76/88 [00:06<00:00, 12.57it/s, training_loss=0.130]
# Epoch 1:  86%|████████▋ | 76/88 [00:06<00:00, 12.57it/s, training_loss=0.236]
# Epoch 1:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.236]
# Epoch 1:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.076]
# Epoch 1:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.156]
# Epoch 1:  91%|█████████ | 80/88 [00:06<00:00, 12.71it/s, training_loss=0.156]
# Epoch 1:  91%|█████████ | 80/88 [00:06<00:00, 12.71it/s, training_loss=0.080]
# Epoch 1:  91%|█████████ | 80/88 [00:06<00:00, 12.71it/s, training_loss=0.024]
# Epoch 1:  93%|█████████▎| 82/88 [00:06<00:00, 12.79it/s, training_loss=0.024]
# Epoch 1:  93%|█████████▎| 82/88 [00:06<00:00, 12.79it/s, training_loss=0.029]
# Epoch 1:  93%|█████████▎| 82/88 [00:06<00:00, 12.79it/s, training_loss=0.294]
# Epoch 1:  95%|█████████▌| 84/88 [00:06<00:00, 12.79it/s, training_loss=0.294]
# Epoch 1:  95%|█████████▌| 84/88 [00:06<00:00, 12.79it/s, training_loss=0.118]
# Epoch 1:  95%|█████████▌| 84/88 [00:06<00:00, 12.79it/s, training_loss=0.132]
# Epoch 1:  98%|█████████▊| 86/88 [00:06<00:00, 12.81it/s, training_loss=0.132]
# Epoch 1:  98%|█████████▊| 86/88 [00:06<00:00, 12.81it/s, training_loss=0.190]
# Epoch 1:  98%|█████████▊| 86/88 [00:06<00:00, 12.81it/s, training_loss=0.089]
# Epoch 1: 100%|██████████| 88/88 [00:06<00:00, 12.86it/s, training_loss=0.089]
#  10%|█         | 1/10 [00:07<01:09,  7.67s/it]
# Epoch 1
# Training loss: 0.4800108624622226
# Epoch 2:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 2:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.141]
# Epoch 2:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.025]
# Epoch 2:   2%|▏         | 2/88 [00:00<00:06, 12.83it/s, training_loss=0.025]
# Epoch 2:   2%|▏         | 2/88 [00:00<00:06, 12.83it/s, training_loss=0.207]
# Epoch 2:   2%|▏         | 2/88 [00:00<00:06, 12.83it/s, training_loss=0.019]
# Epoch 2:   5%|▍         | 4/88 [00:00<00:06, 12.76it/s, training_loss=0.019]
# Epoch 2:   5%|▍         | 4/88 [00:00<00:06, 12.76it/s, training_loss=0.018]
# Epoch 2:   5%|▍         | 4/88 [00:00<00:06, 12.76it/s, training_loss=0.261]
# Epoch 2:   7%|▋         | 6/88 [00:00<00:06, 12.67it/s, training_loss=0.261]
# Epoch 2:   7%|▋         | 6/88 [00:00<00:06, 12.67it/s, training_loss=0.027]
# Epoch 2:   7%|▋         | 6/88 [00:00<00:06, 12.67it/s, training_loss=0.015]
# Epoch 2:   9%|▉         | 8/88 [00:00<00:06, 12.65it/s, training_loss=0.015]
# Epoch 2:   9%|▉         | 8/88 [00:00<00:06, 12.65it/s, training_loss=0.125]
# Epoch 2:   9%|▉         | 8/88 [00:00<00:06, 12.65it/s, training_loss=0.074]
# Epoch 2:  11%|█▏        | 10/88 [00:00<00:06, 12.62it/s, training_loss=0.074]
# Epoch 2:  11%|█▏        | 10/88 [00:00<00:06, 12.62it/s, training_loss=0.018]
# Epoch 2:  11%|█▏        | 10/88 [00:00<00:06, 12.62it/s, training_loss=0.018]
# Epoch 2:  14%|█▎        | 12/88 [00:00<00:06, 12.61it/s, training_loss=0.018]
# Epoch 2:  14%|█▎        | 12/88 [00:01<00:06, 12.61it/s, training_loss=0.017]
# Epoch 2:  14%|█▎        | 12/88 [00:01<00:06, 12.61it/s, training_loss=0.102]
# Epoch 2:  16%|█▌        | 14/88 [00:01<00:05, 12.58it/s, training_loss=0.102]
# Epoch 2:  16%|█▌        | 14/88 [00:01<00:05, 12.58it/s, training_loss=0.027]
# Epoch 2:  16%|█▌        | 14/88 [00:01<00:05, 12.58it/s, training_loss=0.125]
# Epoch 2:  18%|█▊        | 16/88 [00:01<00:05, 12.56it/s, training_loss=0.125]
# Epoch 2:  18%|█▊        | 16/88 [00:01<00:05, 12.56it/s, training_loss=0.182]
# Epoch 2:  18%|█▊        | 16/88 [00:01<00:05, 12.56it/s, training_loss=0.134]
# Epoch 2:  20%|██        | 18/88 [00:01<00:05, 12.56it/s, training_loss=0.134]
# Epoch 2:  20%|██        | 18/88 [00:01<00:05, 12.56it/s, training_loss=0.242]
# Epoch 2:  20%|██        | 18/88 [00:01<00:05, 12.56it/s, training_loss=0.040]
# Epoch 2:  23%|██▎       | 20/88 [00:01<00:05, 12.56it/s, training_loss=0.040]
# Epoch 2:  23%|██▎       | 20/88 [00:01<00:05, 12.56it/s, training_loss=0.015]
# Epoch 2:  23%|██▎       | 20/88 [00:01<00:05, 12.56it/s, training_loss=0.027]
# Epoch 2:  25%|██▌       | 22/88 [00:01<00:05, 12.56it/s, training_loss=0.027]
# Epoch 2:  25%|██▌       | 22/88 [00:01<00:05, 12.56it/s, training_loss=0.014]
# Epoch 2:  25%|██▌       | 22/88 [00:01<00:05, 12.56it/s, training_loss=0.123]
# Epoch 2:  27%|██▋       | 24/88 [00:01<00:05, 12.57it/s, training_loss=0.123]
# Epoch 2:  27%|██▋       | 24/88 [00:01<00:05, 12.57it/s, training_loss=0.012]
# Epoch 2:  27%|██▋       | 24/88 [00:02<00:05, 12.57it/s, training_loss=0.018]
# Epoch 2:  75%|███████▌  | 66/88 [00:05<00:01, 12.52it/s, training_loss=0.223]
# Epoch 2:  77%|███████▋  | 68/88 [00:05<00:01, 12.49it/s, training_loss=0.223]
# Epoch 2:  77%|███████▋  | 68/88 [00:05<00:01, 12.49it/s, training_loss=0.197]
# Epoch 2:  77%|███████▋  | 68/88 [00:05<00:01, 12.49it/s, training_loss=0.003]
# Epoch 2:  80%|███████▉  | 70/88 [00:05<00:01, 12.46it/s, training_loss=0.003]
# Epoch 2:  80%|███████▉  | 70/88 [00:05<00:01, 12.46it/s, training_loss=0.194]
# Epoch 2:  80%|███████▉  | 70/88 [00:05<00:01, 12.46it/s, training_loss=0.004]
# Epoch 2:  82%|████████▏ | 72/88 [00:05<00:01, 12.48it/s, training_loss=0.004]
# Epoch 2:  82%|████████▏ | 72/88 [00:05<00:01, 12.48it/s, training_loss=0.202]
# Epoch 2:  82%|████████▏ | 72/88 [00:05<00:01, 12.48it/s, training_loss=0.005]
# Epoch 2:  84%|████████▍ | 74/88 [00:05<00:01, 12.49it/s, training_loss=0.005]
# Epoch 2:  84%|████████▍ | 74/88 [00:05<00:01, 12.49it/s, training_loss=0.003]
# Epoch 2:  84%|████████▍ | 74/88 [00:06<00:01, 12.49it/s, training_loss=0.113]
# Epoch 2:  86%|████████▋ | 76/88 [00:06<00:00, 12.49it/s, training_loss=0.113]
# Epoch 2:  86%|████████▋ | 76/88 [00:06<00:00, 12.49it/s, training_loss=0.009]
# Epoch 2:  86%|████████▋ | 76/88 [00:06<00:00, 12.49it/s, training_loss=0.004]
# Epoch 2:  89%|████████▊ | 78/88 [00:06<00:00, 12.51it/s, training_loss=0.004]
# Epoch 2:  89%|████████▊ | 78/88 [00:06<00:00, 12.51it/s, training_loss=0.006]
# Epoch 2:  89%|████████▊ | 78/88 [00:06<00:00, 12.51it/s, training_loss=0.142]
# Epoch 2:  91%|█████████ | 80/88 [00:06<00:00, 12.52it/s, training_loss=0.142]
# Epoch 2:  91%|█████████ | 80/88 [00:06<00:00, 12.52it/s, training_loss=0.310]
# Epoch 2:  91%|█████████ | 80/88 [00:06<00:00, 12.52it/s, training_loss=0.004]
# Epoch 2:  93%|█████████▎| 82/88 [00:06<00:00, 12.53it/s, training_loss=0.004]
# Epoch 2:  93%|█████████▎| 82/88 [00:06<00:00, 12.53it/s, training_loss=0.008]
# Epoch 2:  93%|█████████▎| 82/88 [00:06<00:00, 12.53it/s, training_loss=0.060]
# Epoch 2:  95%|█████████▌| 84/88 [00:06<00:00, 12.50it/s, training_loss=0.060]
# Epoch 2:  95%|█████████▌| 84/88 [00:06<00:00, 12.50it/s, training_loss=0.204]
# Epoch 2:  95%|█████████▌| 84/88 [00:06<00:00, 12.50it/s, training_loss=0.004]
# Epoch 2:  98%|█████████▊| 86/88 [00:06<00:00, 12.49it/s, training_loss=0.004]
# Epoch 2:  98%|█████████▊| 86/88 [00:06<00:00, 12.49it/s, training_loss=0.004]
# Epoch 2:  98%|█████████▊| 86/88 [00:07<00:00, 12.49it/s, training_loss=0.004]
# Epoch 2: 100%|██████████| 88/88 [00:07<00:00, 12.53it/s, training_loss=0.004]
#  20%|██        | 2/10 [00:15<01:02,  7.76s/it]
# Epoch 2
# Training loss: 0.22081708727108146
# Epoch 3:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 3:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.002]
# Epoch 3:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.003]
# Epoch 3:   2%|▏         | 2/88 [00:00<00:06, 12.76it/s, training_loss=0.003]
# Epoch 3:   2%|▏         | 2/88 [00:00<00:06, 12.76it/s, training_loss=0.003]
# Epoch 3:   2%|▏         | 2/88 [00:00<00:06, 12.76it/s, training_loss=0.002]
# Epoch 3:   5%|▍         | 4/88 [00:00<00:06, 12.64it/s, training_loss=0.002]
# Epoch 3:   5%|▍         | 4/88 [00:00<00:06, 12.64it/s, training_loss=0.018]
# Epoch 3:   5%|▍         | 4/88 [00:00<00:06, 12.64it/s, training_loss=0.002]
# Epoch 3:   7%|▋         | 6/88 [00:00<00:06, 12.58it/s, training_loss=0.002]
# Epoch 3:   7%|▋         | 6/88 [00:00<00:06, 12.58it/s, training_loss=0.005]
# Epoch 3:   7%|▋         | 6/88 [00:00<00:06, 12.58it/s, training_loss=0.002]
# Epoch 3:   9%|▉         | 8/88 [00:00<00:06, 12.58it/s, training_loss=0.002]
# Epoch 3:   9%|▉         | 8/88 [00:00<00:06, 12.58it/s, training_loss=0.003]
# Epoch 3:   9%|▉         | 8/88 [00:00<00:06, 12.58it/s, training_loss=0.025]
# Epoch 3:  11%|█▏        | 10/88 [00:00<00:06, 12.60it/s, training_loss=0.025]
# Epoch 3:  11%|█▏        | 10/88 [00:00<00:06, 12.60it/s, training_loss=0.006]
# Epoch 3:  11%|█▏        | 10/88 [00:00<00:06, 12.60it/s, training_loss=0.002]
# Epoch 3:  14%|█▎        | 12/88 [00:00<00:06, 12.64it/s, training_loss=0.002]
# Epoch 3:  14%|█▎        | 12/88 [00:01<00:06, 12.64it/s, training_loss=0.002]
# Epoch 3:  14%|█▎        | 12/88 [00:01<00:06, 12.64it/s, training_loss=0.002]
# Epoch 3:  16%|█▌        | 14/88 [00:01<00:05, 12.62it/s, training_loss=0.002]
# Epoch 3:  16%|█▌        | 14/88 [00:01<00:05, 12.62it/s, training_loss=0.002]
# Epoch 3:  16%|█▌        | 14/88 [00:01<00:05, 12.62it/s, training_loss=0.002]
# Epoch 3:  18%|█▊        | 16/88 [00:01<00:05, 12.71it/s, training_loss=0.002]
# Epoch 3:  18%|█▊        | 16/88 [00:01<00:05, 12.71it/s, training_loss=0.002]
# Epoch 3:  18%|█▊        | 16/88 [00:01<00:05, 12.71it/s, training_loss=0.002]
# Epoch 3:  20%|██        | 18/88 [00:01<00:05, 12.66it/s, training_loss=0.002]
# Epoch 3:  20%|██        | 18/88 [00:01<00:05, 12.66it/s, training_loss=0.001]
# Epoch 3:  20%|██        | 18/88 [00:01<00:05, 12.66it/s, training_loss=0.140]
# Epoch 3:  23%|██▎       | 20/88 [00:01<00:05, 12.60it/s, training_loss=0.140]
# Epoch 3:  23%|██▎       | 20/88 [00:01<00:05, 12.60it/s, training_loss=0.001]
# Epoch 3:  23%|██▎       | 20/88 [00:01<00:05, 12.60it/s, training_loss=0.002]
# Epoch 3:  25%|██▌       | 22/88 [00:01<00:05, 12.55it/s, training_loss=0.002]
# Epoch 3:  25%|██▌       | 22/88 [00:01<00:05, 12.55it/s, training_loss=0.001]
# Epoch 3:  25%|██▌       | 22/88 [00:01<00:05, 12.55it/s, training_loss=0.001]
# Epoch 3:  27%|██▋       | 24/88 [00:01<00:05, 12.50it/s, training_loss=0.001]
# Epoch 3:  27%|██▋       | 24/88 [00:01<00:05, 12.50it/s, training_loss=0.002]
# Epoch 3:  27%|██▋       | 24/88 [00:02<00:05, 12.50it/s, training_loss=0.001]
# Epoch 3:  30%|██▉       | 26/88 [00:02<00:04, 12.61it/s, training_loss=0.001]
# Epoch 3:  30%|██▉       | 26/88 [00:02<00:04, 12.61it/s, training_loss=0.001]
# Epoch 3:  30%|██▉       | 26/88 [00:02<00:04, 12.61it/s, training_loss=0.001]
# Epoch 3:  32%|███▏      | 28/88 [00:02<00:04, 12.67it/s, training_loss=0.001]
# Epoch 3:  32%|███▏      | 28/88 [00:02<00:04, 12.67it/s, training_loss=0.001]
# Epoch 3:  32%|███▏      | 28/88 [00:02<00:04, 12.67it/s, training_loss=0.001]
# Epoch 3:  34%|███▍      | 30/88 [00:02<00:04, 12.69it/s, training_loss=0.001]
# Epoch 3:  34%|███▍      | 30/88 [00:02<00:04, 12.69it/s, training_loss=0.001]
# Epoch 3:  34%|███▍      | 30/88 [00:02<00:04, 12.69it/s, training_loss=0.001]
# Epoch 3:  36%|███▋      | 32/88 [00:02<00:04, 12.71it/s, training_loss=0.001]
# Epoch 3:  36%|███▋      | 32/88 [00:02<00:04, 12.71it/s, training_loss=0.094]
# Epoch 3:  36%|███▋      | 32/88 [00:02<00:04, 12.71it/s, training_loss=0.001]
# Epoch 3:  39%|███▊      | 34/88 [00:02<00:04, 12.77it/s, training_loss=0.001]
# Epoch 3:  39%|███▊      | 34/88 [00:02<00:04, 12.77it/s, training_loss=0.190]
# Epoch 3:  39%|███▊      | 34/88 [00:02<00:04, 12.77it/s, training_loss=0.053]
# Epoch 3:  41%|████      | 36/88 [00:02<00:04, 12.79it/s, training_loss=0.053]
# Epoch 3:  41%|████      | 36/88 [00:02<00:04, 12.79it/s, training_loss=0.001]
# Epoch 3:  41%|████      | 36/88 [00:02<00:04, 12.79it/s, training_loss=0.001]
# Epoch 3:  43%|████▎     | 38/88 [00:02<00:03, 12.78it/s, training_loss=0.001]
# Epoch 3:  43%|████▎     | 38/88 [00:03<00:03, 12.78it/s, training_loss=0.207]
# Epoch 3:  43%|████▎     | 38/88 [00:03<00:03, 12.78it/s, training_loss=0.005]
# Epoch 3:  45%|████▌     | 40/88 [00:03<00:03, 12.72it/s, training_loss=0.005]
# Epoch 3:  45%|████▌     | 40/88 [00:03<00:03, 12.72it/s, training_loss=0.001]
# Epoch 3:  45%|████▌     | 40/88 [00:03<00:03, 12.72it/s, training_loss=0.001]
# Epoch 3:  48%|████▊     | 42/88 [00:03<00:03, 12.67it/s, training_loss=0.001]
# Epoch 3:  48%|████▊     | 42/88 [00:03<00:03, 12.67it/s, training_loss=0.002]
# Epoch 3:  48%|████▊     | 42/88 [00:03<00:03, 12.67it/s, training_loss=0.092]
# Epoch 3:  50%|█████     | 44/88 [00:03<00:03, 12.64it/s, training_loss=0.092]
# Epoch 3:  50%|█████     | 44/88 [00:03<00:03, 12.64it/s, training_loss=0.001]
# Epoch 3:  50%|█████     | 44/88 [00:03<00:03, 12.64it/s, training_loss=0.001]
# Epoch 3:  52%|█████▏    | 46/88 [00:03<00:03, 12.60it/s, training_loss=0.001]
# Epoch 3:  52%|█████▏    | 46/88 [00:03<00:03, 12.60it/s, training_loss=0.001]
# Epoch 3:  52%|█████▏    | 46/88 [00:03<00:03, 12.60it/s, training_loss=0.026]
# Epoch 3:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.026]
# Epoch 3:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.203]
# Epoch 3:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.274]
# Epoch 3:  57%|█████▋    | 50/88 [00:03<00:03, 12.52it/s, training_loss=0.274]
# Epoch 3:  57%|█████▋    | 50/88 [00:04<00:03, 12.52it/s, training_loss=0.001]
# Epoch 3:  57%|█████▋    | 50/88 [00:04<00:03, 12.52it/s, training_loss=0.002]
# Epoch 3:  59%|█████▉    | 52/88 [00:04<00:02, 12.52it/s, training_loss=0.002]
# Epoch 3:  59%|█████▉    | 52/88 [00:04<00:02, 12.52it/s, training_loss=0.001]
# Epoch 3:  59%|█████▉    | 52/88 [00:04<00:02, 12.52it/s, training_loss=0.001]
# Epoch 3:  61%|██████▏   | 54/88 [00:04<00:02, 12.60it/s, training_loss=0.001]
# Epoch 3:  61%|██████▏   | 54/88 [00:04<00:02, 12.60it/s, training_loss=0.235]
# Epoch 3:  61%|██████▏   | 54/88 [00:04<00:02, 12.60it/s, training_loss=0.001]
# Epoch 3:  64%|██████▎   | 56/88 [00:04<00:02, 12.65it/s, training_loss=0.001]
# Epoch 3:  64%|██████▎   | 56/88 [00:04<00:02, 12.65it/s, training_loss=0.001]
# Epoch 3:  64%|██████▎   | 56/88 [00:04<00:02, 12.65it/s, training_loss=0.001]
# Epoch 3:  66%|██████▌   | 58/88 [00:04<00:02, 12.69it/s, training_loss=0.001]
# Epoch 3:  66%|██████▌   | 58/88 [00:04<00:02, 12.69it/s, training_loss=0.001]
# Epoch 3:  66%|██████▌   | 58/88 [00:04<00:02, 12.69it/s, training_loss=0.001]
# Epoch 3:  68%|██████▊   | 60/88 [00:04<00:02, 12.74it/s, training_loss=0.001]
# Epoch 3:  68%|██████▊   | 60/88 [00:04<00:02, 12.74it/s, training_loss=0.337]
# Epoch 3:  68%|██████▊   | 60/88 [00:04<00:02, 12.74it/s, training_loss=0.001]
# Epoch 3:  70%|███████   | 62/88 [00:04<00:02, 12.75it/s, training_loss=0.001]
# Epoch 3:  70%|███████   | 62/88 [00:04<00:02, 12.75it/s, training_loss=0.222]
# Epoch 3:  70%|███████   | 62/88 [00:05<00:02, 12.75it/s, training_loss=0.003]
# Epoch 3:  73%|███████▎  | 64/88 [00:05<00:01, 12.74it/s, training_loss=0.003]
# Epoch 3:  73%|███████▎  | 64/88 [00:05<00:01, 12.74it/s, training_loss=0.172]
# Epoch 3:  73%|███████▎  | 64/88 [00:05<00:01, 12.74it/s, training_loss=0.001]
# Epoch 3:  75%|███████▌  | 66/88 [00:05<00:01, 12.72it/s, training_loss=0.001]
# Epoch 3:  75%|███████▌  | 66/88 [00:05<00:01, 12.72it/s, training_loss=0.002]
# Epoch 3:  75%|███████▌  | 66/88 [00:05<00:01, 12.72it/s, training_loss=0.002]
# Epoch 3:  77%|███████▋  | 68/88 [00:05<00:01, 12.73it/s, training_loss=0.002]
# Epoch 3:  77%|███████▋  | 68/88 [00:05<00:01, 12.73it/s, training_loss=0.001]
# Epoch 3:  77%|███████▋  | 68/88 [00:05<00:01, 12.73it/s, training_loss=0.130]
# Epoch 3:  80%|███████▉  | 70/88 [00:05<00:01, 12.78it/s, training_loss=0.130]
# Epoch 3:  80%|███████▉  | 70/88 [00:05<00:01, 12.78it/s, training_loss=0.180]
# Epoch 3:  80%|███████▉  | 70/88 [00:05<00:01, 12.78it/s, training_loss=0.001]
# Epoch 3:  82%|████████▏ | 72/88 [00:05<00:01, 12.81it/s, training_loss=0.001]
# Epoch 3:  82%|████████▏ | 72/88 [00:05<00:01, 12.81it/s, training_loss=0.002]
# Epoch 3:  82%|████████▏ | 72/88 [00:05<00:01, 12.81it/s, training_loss=0.002]
# Epoch 3:  84%|████████▍ | 74/88 [00:05<00:01, 12.76it/s, training_loss=0.002]
# Epoch 3:  84%|████████▍ | 74/88 [00:05<00:01, 12.76it/s, training_loss=0.002]
# Epoch 3:  84%|████████▍ | 74/88 [00:05<00:01, 12.76it/s, training_loss=0.244]
# Epoch 3:  86%|████████▋ | 76/88 [00:06<00:00, 12.66it/s, training_loss=0.244]
# Epoch 3:  86%|████████▋ | 76/88 [00:06<00:00, 12.66it/s, training_loss=0.002]
# Epoch 3:  86%|████████▋ | 76/88 [00:06<00:00, 12.66it/s, training_loss=0.266]
# Epoch 3:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.266]
# Epoch 3:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.003]
# Epoch 3:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.003]
# Epoch 3:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.003]
# Epoch 3:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.195]
# Epoch 3:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 82/88 [00:06<00:00, 12.64it/s, training_loss=0.002]
# Epoch 3:  93%|█████████▎| 82/88 [00:06<00:00, 12.64it/s, training_loss=0.001]
# Epoch 3:  93%|█████████▎| 82/88 [00:06<00:00, 12.64it/s, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 84/88 [00:06<00:00, 12.62it/s, training_loss=0.001]
# Epoch 3:  95%|█████████▌| 84/88 [00:06<00:00, 12.62it/s, training_loss=0.031]
# Epoch 3:  95%|█████████▌| 84/88 [00:06<00:00, 12.62it/s, training_loss=0.002]
# Epoch 3:  98%|█████████▊| 86/88 [00:06<00:00, 12.65it/s, training_loss=0.002]
# Epoch 3:  98%|█████████▊| 86/88 [00:06<00:00, 12.65it/s, training_loss=0.019]
# Epoch 3:  98%|█████████▊| 86/88 [00:06<00:00, 12.65it/s, training_loss=0.001]
# Epoch 3: 100%|██████████| 88/88 [00:06<00:00, 12.76it/s, training_loss=0.001]
#  30%|███       | 3/10 [00:23<00:54,  7.75s/it]
# Epoch 3
# Training loss: 0.11829078564981253
# Epoch 4:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 4:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.001]
# Epoch 4:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.001]
# Epoch 4:   2%|▏         | 2/88 [00:00<00:06, 13.00it/s, training_loss=0.001]
# Epoch 4:   2%|▏         | 2/88 [00:00<00:06, 13.00it/s, training_loss=0.001]
# Epoch 4:   2%|▏         | 2/88 [00:00<00:06, 13.00it/s, training_loss=0.001]
# Epoch 4:   5%|▍         | 4/88 [00:00<00:06, 12.91it/s, training_loss=0.001]
# Epoch 4:   5%|▍         | 4/88 [00:00<00:06, 12.91it/s, training_loss=0.002]
# Epoch 4:   5%|▍         | 4/88 [00:00<00:06, 12.91it/s, training_loss=0.001]
# Epoch 4:   7%|▋         | 6/88 [00:00<00:06, 12.81it/s, training_loss=0.001]
# Epoch 4:   7%|▋         | 6/88 [00:00<00:06, 12.81it/s, training_loss=0.002]
# Epoch 4:   7%|▋         | 6/88 [00:00<00:06, 12.81it/s, training_loss=0.001]
# Epoch 4:   9%|▉         | 8/88 [00:00<00:06, 12.78it/s, training_loss=0.001]
# Epoch 4:   9%|▉         | 8/88 [00:00<00:06, 12.78it/s, training_loss=0.008]
# Epoch 4:   9%|▉         | 8/88 [00:00<00:06, 12.78it/s, training_loss=0.001]
# Epoch 4:  11%|█▏        | 10/88 [00:00<00:06, 12.71it/s, training_loss=0.001]
# Epoch 4:  11%|█▏        | 10/88 [00:00<00:06, 12.71it/s, training_loss=0.001]
# Epoch 4:  11%|█▏        | 10/88 [00:00<00:06, 12.71it/s, training_loss=0.001]
# Epoch 4:  14%|█▎        | 12/88 [00:00<00:05, 12.69it/s, training_loss=0.001]
# Epoch 4:  14%|█▎        | 12/88 [00:01<00:05, 12.69it/s, training_loss=0.034]
# Epoch 4:  14%|█▎        | 12/88 [00:01<00:05, 12.69it/s, training_loss=0.001]
# Epoch 4:  39%|███▊      | 34/88 [00:02<00:04, 12.68it/s, training_loss=0.001]
# Epoch 4:  39%|███▊      | 34/88 [00:02<00:04, 12.68it/s, training_loss=0.001]
# Epoch 4:  41%|████      | 36/88 [00:02<00:04, 12.72it/s, training_loss=0.001]
# Epoch 4:  41%|████      | 36/88 [00:02<00:04, 12.72it/s, training_loss=0.001]
# Epoch 4:  41%|████      | 36/88 [00:02<00:04, 12.72it/s, training_loss=0.001]
# Epoch 4:  43%|████▎     | 38/88 [00:02<00:03, 12.73it/s, training_loss=0.001]
# Epoch 4:  43%|████▎     | 38/88 [00:03<00:03, 12.73it/s, training_loss=0.001]
# Epoch 4:  43%|████▎     | 38/88 [00:03<00:03, 12.73it/s, training_loss=0.001]
# Epoch 4:  45%|████▌     | 40/88 [00:03<00:03, 12.74it/s, training_loss=0.001]
# Epoch 4:  45%|████▌     | 40/88 [00:03<00:03, 12.74it/s, training_loss=0.001]
# Epoch 4:  45%|████▌     | 40/88 [00:03<00:03, 12.74it/s, training_loss=0.001]
# Epoch 4:  48%|████▊     | 42/88 [00:03<00:03, 12.68it/s, training_loss=0.001]
# Epoch 4:  48%|████▊     | 42/88 [00:03<00:03, 12.68it/s, training_loss=0.001]
# Epoch 4:  48%|████▊     | 42/88 [00:03<00:03, 12.68it/s, training_loss=0.001]
# Epoch 4:  50%|█████     | 44/88 [00:03<00:03, 12.70it/s, training_loss=0.001]
# Epoch 4:  50%|█████     | 44/88 [00:03<00:03, 12.70it/s, training_loss=0.001]
# Epoch 4:  50%|█████     | 44/88 [00:03<00:03, 12.70it/s, training_loss=0.217]
# Epoch 4:  52%|█████▏    | 46/88 [00:03<00:03, 12.69it/s, training_loss=0.217]
# Epoch 4:  52%|█████▏    | 46/88 [00:03<00:03, 12.69it/s, training_loss=0.010]
# Epoch 4:  52%|█████▏    | 46/88 [00:03<00:03, 12.69it/s, training_loss=0.001]
# Epoch 4:  55%|█████▍    | 48/88 [00:03<00:03, 12.66it/s, training_loss=0.001]
# Epoch 4:  55%|█████▍    | 48/88 [00:03<00:03, 12.66it/s, training_loss=0.001]
# Epoch 4:  55%|█████▍    | 48/88 [00:03<00:03, 12.66it/s, training_loss=0.001]
# Epoch 4:  57%|█████▋    | 50/88 [00:03<00:02, 12.67it/s, training_loss=0.001]
# Epoch 4:  57%|█████▋    | 50/88 [00:04<00:02, 12.67it/s, training_loss=0.001]
# Epoch 4:  57%|█████▋    | 50/88 [00:04<00:02, 12.67it/s, training_loss=0.001]
# Epoch 4:  59%|█████▉    | 52/88 [00:04<00:02, 12.70it/s, training_loss=0.001]
# Epoch 4:  59%|█████▉    | 52/88 [00:04<00:02, 12.70it/s, training_loss=0.001]
# Epoch 4:  59%|█████▉    | 52/88 [00:04<00:02, 12.70it/s, training_loss=0.126]
# Epoch 4:  61%|██████▏   | 54/88 [00:04<00:02, 12.65it/s, training_loss=0.126]
# Epoch 4:  61%|██████▏   | 54/88 [00:04<00:02, 12.65it/s, training_loss=0.001]
# Epoch 4:  86%|████████▋ | 76/88 [00:06<00:00, 12.62it/s, training_loss=0.000]
# Epoch 4:  86%|████████▋ | 76/88 [00:06<00:00, 12.62it/s, training_loss=0.003]
# Epoch 4:  86%|████████▋ | 76/88 [00:06<00:00, 12.62it/s, training_loss=0.001]
# Epoch 4:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.001]
# Epoch 4:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.001]
# Epoch 4:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.001]
# Epoch 4:  91%|█████████ | 80/88 [00:06<00:00, 12.60it/s, training_loss=0.001]
# Epoch 4:  91%|█████████ | 80/88 [00:06<00:00, 12.60it/s, training_loss=0.001]
# Epoch 4:  91%|█████████ | 80/88 [00:06<00:00, 12.60it/s, training_loss=0.000]
# Epoch 4:  93%|█████████▎| 82/88 [00:06<00:00, 12.58it/s, training_loss=0.000]
# Epoch 4:  93%|█████████▎| 82/88 [00:06<00:00, 12.58it/s, training_loss=0.001]
# Epoch 4:  93%|█████████▎| 82/88 [00:06<00:00, 12.58it/s, training_loss=0.001]
# Epoch 4:  95%|█████████▌| 84/88 [00:06<00:00, 12.54it/s, training_loss=0.001]
# Epoch 4:  95%|█████████▌| 84/88 [00:06<00:00, 12.54it/s, training_loss=0.000]
# Epoch 4:  95%|█████████▌| 84/88 [00:06<00:00, 12.54it/s, training_loss=0.001]
# Epoch 4:  98%|█████████▊| 86/88 [00:06<00:00, 12.51it/s, training_loss=0.001]
# Epoch 4:  98%|█████████▊| 86/88 [00:06<00:00, 12.51it/s, training_loss=0.002]
# Epoch 4:  98%|█████████▊| 86/88 [00:06<00:00, 12.51it/s, training_loss=0.000]
# Epoch 4: 100%|██████████| 88/88 [00:06<00:00, 12.55it/s, training_loss=0.000]
#  40%|████      | 4/10 [00:30<00:46,  7.74s/it]
# Epoch 4
# Training loss: 0.029996472400274466
# Epoch 5:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 5:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.000]
# Epoch 5:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.001]
# Epoch 5:   2%|▏         | 2/88 [00:00<00:06, 12.69it/s, training_loss=0.001]
# Epoch 5:   2%|▏         | 2/88 [00:00<00:06, 12.69it/s, training_loss=0.000]
# Epoch 5:   2%|▏         | 2/88 [00:00<00:06, 12.69it/s, training_loss=0.001]
# Epoch 5:   5%|▍         | 4/88 [00:00<00:06, 12.53it/s, training_loss=0.001]
# Epoch 5:   5%|▍         | 4/88 [00:00<00:06, 12.53it/s, training_loss=0.001]
# Epoch 5:   5%|▍         | 4/88 [00:00<00:06, 12.53it/s, training_loss=0.000]
# Epoch 5:   7%|▋         | 6/88 [00:00<00:06, 12.48it/s, training_loss=0.000]
# Epoch 5:   7%|▋         | 6/88 [00:00<00:06, 12.48it/s, training_loss=0.001]
# Epoch 5:   7%|▋         | 6/88 [00:00<00:06, 12.48it/s, training_loss=0.000]
# Epoch 5:   9%|▉         | 8/88 [00:00<00:06, 12.49it/s, training_loss=0.000]
# Epoch 5:   9%|▉         | 8/88 [00:00<00:06, 12.49it/s, training_loss=0.093]
# Epoch 5:   9%|▉         | 8/88 [00:00<00:06, 12.49it/s, training_loss=0.001]
# Epoch 5:  11%|█▏        | 10/88 [00:00<00:06, 12.46it/s, training_loss=0.001]
# Epoch 5:  11%|█▏        | 10/88 [00:00<00:06, 12.46it/s, training_loss=0.001]
# Epoch 5:  11%|█▏        | 10/88 [00:00<00:06, 12.46it/s, training_loss=0.000]
# Epoch 5:  14%|█▎        | 12/88 [00:00<00:06, 12.46it/s, training_loss=0.000]
# Epoch 5:  14%|█▎        | 12/88 [00:01<00:06, 12.46it/s, training_loss=0.000]
# Epoch 5:  14%|█▎        | 12/88 [00:01<00:06, 12.46it/s, training_loss=0.000]
# Epoch 5:  16%|█▌        | 14/88 [00:01<00:05, 12.44it/s, training_loss=0.000]
# Epoch 5:  16%|█▌        | 14/88 [00:01<00:05, 12.44it/s, training_loss=0.000]
# Epoch 5:  16%|█▌        | 14/88 [00:01<00:05, 12.44it/s, training_loss=0.000]
# Epoch 5:  18%|█▊        | 16/88 [00:01<00:05, 12.45it/s, training_loss=0.000]
# Epoch 5:  18%|█▊        | 16/88 [00:01<00:05, 12.45it/s, training_loss=0.000]
# Epoch 5:  18%|█▊        | 16/88 [00:01<00:05, 12.45it/s, training_loss=0.220]
# Epoch 5:  20%|██        | 18/88 [00:01<00:05, 12.49it/s, training_loss=0.220]
# Epoch 5:  20%|██        | 18/88 [00:01<00:05, 12.49it/s, training_loss=0.180]
# Epoch 5:  20%|██        | 18/88 [00:01<00:05, 12.49it/s, training_loss=0.003]
# Epoch 5:  23%|██▎       | 20/88 [00:01<00:05, 12.52it/s, training_loss=0.003]
# Epoch 5:  23%|██▎       | 20/88 [00:01<00:05, 12.52it/s, training_loss=0.000]
# Epoch 5:  23%|██▎       | 20/88 [00:01<00:05, 12.52it/s, training_loss=0.000]
# Epoch 5:  25%|██▌       | 22/88 [00:01<00:05, 12.62it/s, training_loss=0.000]
# Epoch 5:  25%|██▌       | 22/88 [00:01<00:05, 12.62it/s, training_loss=0.000]
# Epoch 5:  25%|██▌       | 22/88 [00:01<00:05, 12.62it/s, training_loss=0.000]
# Epoch 5:  27%|██▋       | 24/88 [00:01<00:05, 12.64it/s, training_loss=0.000]
# Epoch 5:  27%|██▋       | 24/88 [00:01<00:05, 12.64it/s, training_loss=0.001]
# Epoch 5:  27%|██▋       | 24/88 [00:02<00:05, 12.64it/s, training_loss=0.001]
# Epoch 5:  30%|██▉       | 26/88 [00:02<00:04, 12.60it/s, training_loss=0.001]
# Epoch 5:  30%|██▉       | 26/88 [00:02<00:04, 12.60it/s, training_loss=0.001]
# Epoch 5:  30%|██▉       | 26/88 [00:02<00:04, 12.60it/s, training_loss=0.000]
# Epoch 5:  32%|███▏      | 28/88 [00:02<00:04, 12.67it/s, training_loss=0.000]
# Epoch 5:  32%|███▏      | 28/88 [00:02<00:04, 12.67it/s, training_loss=0.001]
# Epoch 5:  32%|███▏      | 28/88 [00:02<00:04, 12.67it/s, training_loss=0.005]
# Epoch 5:  34%|███▍      | 30/88 [00:02<00:04, 12.66it/s, training_loss=0.005]
# Epoch 5:  34%|███▍      | 30/88 [00:02<00:04, 12.66it/s, training_loss=0.000]
# Epoch 5:  34%|███▍      | 30/88 [00:02<00:04, 12.66it/s, training_loss=0.000]
# Epoch 5:  36%|███▋      | 32/88 [00:02<00:04, 12.70it/s, training_loss=0.000]
# Epoch 5:  36%|███▋      | 32/88 [00:02<00:04, 12.70it/s, training_loss=0.000]
# Epoch 5:  36%|███▋      | 32/88 [00:02<00:04, 12.70it/s, training_loss=0.000]
# Epoch 5:  39%|███▊      | 34/88 [00:02<00:04, 12.71it/s, training_loss=0.000]
# Epoch 5:  39%|███▊      | 34/88 [00:02<00:04, 12.71it/s, training_loss=0.001]
# Epoch 5:  39%|███▊      | 34/88 [00:02<00:04, 12.71it/s, training_loss=0.251]
# Epoch 5:  41%|████      | 36/88 [00:02<00:04, 12.69it/s, training_loss=0.251]
# Epoch 5:  41%|████      | 36/88 [00:02<00:04, 12.69it/s, training_loss=0.001]
# Epoch 5:  41%|████      | 36/88 [00:03<00:04, 12.69it/s, training_loss=0.001]
# Epoch 5:  43%|████▎     | 38/88 [00:03<00:03, 12.70it/s, training_loss=0.001]
# Epoch 5:  43%|████▎     | 38/88 [00:03<00:03, 12.70it/s, training_loss=0.000]
# Epoch 5:  43%|████▎     | 38/88 [00:03<00:03, 12.70it/s, training_loss=0.003]
# Epoch 5:  45%|████▌     | 40/88 [00:03<00:03, 12.73it/s, training_loss=0.003]
# Epoch 5:  45%|████▌     | 40/88 [00:03<00:03, 12.73it/s, training_loss=0.001]
# Epoch 5:  45%|████▌     | 40/88 [00:03<00:03, 12.73it/s, training_loss=0.000]
# Epoch 5:  48%|████▊     | 42/88 [00:03<00:03, 12.73it/s, training_loss=0.000]
# Epoch 5:  48%|████▊     | 42/88 [00:03<00:03, 12.73it/s, training_loss=0.001]
# Epoch 5:  48%|████▊     | 42/88 [00:03<00:03, 12.73it/s, training_loss=0.000]
# Epoch 5:  50%|█████     | 44/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 5:  50%|█████     | 44/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 5:  50%|█████     | 44/88 [00:03<00:03, 12.78it/s, training_loss=0.004]
# Epoch 5:  52%|█████▏    | 46/88 [00:03<00:03, 12.78it/s, training_loss=0.004]
# Epoch 5:  52%|█████▏    | 46/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 5:  52%|█████▏    | 46/88 [00:03<00:03, 12.78it/s, training_loss=0.001]
# Epoch 5:  55%|█████▍    | 48/88 [00:03<00:03, 12.78it/s, training_loss=0.001]
# Epoch 5:  55%|█████▍    | 48/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 5:  55%|█████▍    | 48/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 5:  57%|█████▋    | 50/88 [00:03<00:02, 12.70it/s, training_loss=0.000]
# Epoch 5:  57%|█████▋    | 50/88 [00:04<00:02, 12.70it/s, training_loss=0.001]
# Epoch 5:  57%|█████▋    | 50/88 [00:04<00:02, 12.70it/s, training_loss=0.000]
# Epoch 5:  59%|█████▉    | 52/88 [00:04<00:02, 12.66it/s, training_loss=0.000]
# Epoch 5:  59%|█████▉    | 52/88 [00:04<00:02, 12.66it/s, training_loss=0.000]
# Epoch 5:  59%|█████▉    | 52/88 [00:04<00:02, 12.66it/s, training_loss=0.000]
# Epoch 5:  61%|██████▏   | 54/88 [00:04<00:02, 12.65it/s, training_loss=0.000]
# ...
# Epoch 9:  48%|████▊     | 42/88 [00:03<00:03, 12.53it/s, training_loss=0.000]
# Epoch 9:  50%|█████     | 44/88 [00:03<00:03, 12.52it/s, training_loss=0.000]
# Epoch 9:  50%|█████     | 44/88 [00:03<00:03, 12.52it/s, training_loss=0.000]
# Epoch 9:  50%|█████     | 44/88 [00:03<00:03, 12.52it/s, training_loss=0.000]
# Epoch 9:  52%|█████▏    | 46/88 [00:03<00:03, 12.49it/s, training_loss=0.000]
# Epoch 9:  52%|█████▏    | 46/88 [00:03<00:03, 12.49it/s, training_loss=0.000]
# Epoch 9:  52%|█████▏    | 46/88 [00:03<00:03, 12.49it/s, training_loss=0.000]
# Epoch 9:  55%|█████▍    | 48/88 [00:03<00:03, 12.52it/s, training_loss=0.000]
# Epoch 9:  55%|█████▍    | 48/88 [00:03<00:03, 12.52it/s, training_loss=0.000]
# Epoch 9:  55%|█████▍    | 48/88 [00:03<00:03, 12.52it/s, training_loss=0.000]
# Epoch 9:  57%|█████▋    | 50/88 [00:03<00:03, 12.60it/s, training_loss=0.000]
# Epoch 9:  57%|█████▋    | 50/88 [00:04<00:03, 12.60it/s, training_loss=0.000]
# Epoch 9:  57%|█████▋    | 50/88 [00:04<00:03, 12.60it/s, training_loss=0.000]
# Epoch 9:  59%|█████▉    | 52/88 [00:04<00:02, 12.63it/s, training_loss=0.000]
# Epoch 9:  59%|█████▉    | 52/88 [00:04<00:02, 12.63it/s, training_loss=0.000]
# Epoch 9:  59%|█████▉    | 52/88 [00:04<00:02, 12.63it/s, training_loss=0.000]
# Epoch 9:  61%|██████▏   | 54/88 [00:04<00:02, 12.68it/s, training_loss=0.000]
# Epoch 9:  61%|██████▏   | 54/88 [00:04<00:02, 12.68it/s, training_loss=0.000]
# Epoch 9:  61%|██████▏   | 54/88 [00:04<00:02, 12.68it/s, training_loss=0.000]
# Epoch 9:  64%|██████▎   | 56/88 [00:04<00:02, 12.70it/s, training_loss=0.000]
# Epoch 9:  64%|██████▎   | 56/88 [00:04<00:02, 12.70it/s, training_loss=0.000]
# Epoch 9:  64%|██████▎   | 56/88 [00:04<00:02, 12.70it/s, training_loss=0.000]
# Epoch 9:  66%|██████▌   | 58/88 [00:04<00:02, 12.69it/s, training_loss=0.000]
# Epoch 9:  66%|██████▌   | 58/88 [00:04<00:02, 12.69it/s, training_loss=0.000]
# Epoch 9:  66%|██████▌   | 58/88 [00:04<00:02, 12.69it/s, training_loss=0.000]
# Epoch 9:  68%|██████▊   | 60/88 [00:04<00:02, 12.73it/s, training_loss=0.000]
# Epoch 9:  68%|██████▊   | 60/88 [00:04<00:02, 12.73it/s, training_loss=0.000]
# Epoch 9:  68%|██████▊   | 60/88 [00:04<00:02, 12.73it/s, training_loss=0.000]
# Epoch 9:  70%|███████   | 62/88 [00:04<00:02, 12.68it/s, training_loss=0.000]
# Epoch 9:  70%|███████   | 62/88 [00:05<00:02, 12.68it/s, training_loss=0.000]
# Epoch 9:  70%|███████   | 62/88 [00:05<00:02, 12.68it/s, training_loss=0.000]
# Epoch 9:  73%|███████▎  | 64/88 [00:05<00:01, 12.68it/s, training_loss=0.000]
# Epoch 9:  73%|███████▎  | 64/88 [00:05<00:01, 12.68it/s, training_loss=0.000]
# Epoch 9:  73%|███████▎  | 64/88 [00:05<00:01, 12.68it/s, training_loss=0.000]
# Epoch 9:  75%|███████▌  | 66/88 [00:05<00:01, 12.58it/s, training_loss=0.000]
# Epoch 9:  75%|███████▌  | 66/88 [00:05<00:01, 12.58it/s, training_loss=0.000]
# Epoch 9:  75%|███████▌  | 66/88 [00:05<00:01, 12.58it/s, training_loss=0.000]
# Epoch 9:  77%|███████▋  | 68/88 [00:05<00:01, 12.60it/s, training_loss=0.000]
# Epoch 9:  77%|███████▋  | 68/88 [00:05<00:01, 12.60it/s, training_loss=0.001]
# Epoch 9:  77%|███████▋  | 68/88 [00:05<00:01, 12.60it/s, training_loss=0.000]
# Epoch 9:  80%|███████▉  | 70/88 [00:05<00:01, 12.48it/s, training_loss=0.000]
# Epoch 9:  80%|███████▉  | 70/88 [00:05<00:01, 12.48it/s, training_loss=0.000]
# Epoch 9:  80%|███████▉  | 70/88 [00:05<00:01, 12.48it/s, training_loss=0.000]
# Epoch 9:  82%|████████▏ | 72/88 [00:05<00:01, 12.58it/s, training_loss=0.000]
# Epoch 9:  82%|████████▏ | 72/88 [00:05<00:01, 12.58it/s, training_loss=0.000]
# Epoch 9:  82%|████████▏ | 72/88 [00:05<00:01, 12.58it/s, training_loss=0.000]
# Epoch 9:  84%|████████▍ | 74/88 [00:05<00:01, 12.66it/s, training_loss=0.000]
# Epoch 9:  84%|████████▍ | 74/88 [00:05<00:01, 12.66it/s, training_loss=0.000]
# Epoch 9:  84%|████████▍ | 74/88 [00:06<00:01, 12.66it/s, training_loss=0.000]
# Epoch 9:  86%|████████▋ | 76/88 [00:06<00:00, 12.73it/s, training_loss=0.000]
# Epoch 9:  86%|████████▋ | 76/88 [00:06<00:00, 12.73it/s, training_loss=0.000]
# Epoch 9:  86%|████████▋ | 76/88 [00:06<00:00, 12.73it/s, training_loss=0.000]
# Epoch 9:  89%|████████▊ | 78/88 [00:06<00:00, 12.72it/s, training_loss=0.000]
# Epoch 9:  89%|████████▊ | 78/88 [00:06<00:00, 12.72it/s, training_loss=0.000]
# Epoch 9:  89%|████████▊ | 78/88 [00:06<00:00, 12.72it/s, training_loss=0.000]
# Epoch 9:  91%|█████████ | 80/88 [00:06<00:00, 12.74it/s, training_loss=0.000]
# Epoch 9:  91%|█████████ | 80/88 [00:06<00:00, 12.74it/s, training_loss=0.000]
# Epoch 9:  91%|█████████ | 80/88 [00:06<00:00, 12.74it/s, training_loss=0.000]
# Epoch 9:  93%|█████████▎| 82/88 [00:06<00:00, 12.81it/s, training_loss=0.000]
# Epoch 9:  93%|█████████▎| 82/88 [00:06<00:00, 12.81it/s, training_loss=0.000]
# Epoch 9:  93%|█████████▎| 82/88 [00:06<00:00, 12.81it/s, training_loss=0.000]
# Epoch 9:  95%|█████████▌| 84/88 [00:06<00:00, 12.79it/s, training_loss=0.000]
# Epoch 9:  95%|█████████▌| 84/88 [00:06<00:00, 12.79it/s, training_loss=0.000]
# Epoch 9:  95%|█████████▌| 84/88 [00:06<00:00, 12.79it/s, training_loss=0.000]
# Epoch 9:  98%|█████████▊| 86/88 [00:06<00:00, 12.78it/s, training_loss=0.000]
# Epoch 9:  98%|█████████▊| 86/88 [00:06<00:00, 12.78it/s, training_loss=0.000]
# Epoch 9:  98%|█████████▊| 86/88 [00:06<00:00, 12.78it/s, training_loss=0.000]
# Epoch 9: 100%|██████████| 88/88 [00:06<00:00, 12.88it/s, training_loss=0.000]
#  90%|█████████ | 9/10 [01:09<00:07,  7.72s/it]
# Epoch 9
# Training loss: 0.0003585194734279701
# Epoch 10:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 10:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.000]
# Epoch 10:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.000]
# Epoch 10:   2%|▏         | 2/88 [00:00<00:06, 12.88it/s, training_loss=0.000]
# Epoch 10:   2%|▏         | 2/88 [00:00<00:06, 12.88it/s, training_loss=0.000]
# Epoch 10:   2%|▏         | 2/88 [00:00<00:06, 12.88it/s, training_loss=0.000]
# Epoch 10:   5%|▍         | 4/88 [00:00<00:06, 12.78it/s, training_loss=0.000]
# Epoch 10:   5%|▍         | 4/88 [00:00<00:06, 12.78it/s, training_loss=0.000]
# Epoch 10:   5%|▍         | 4/88 [00:00<00:06, 12.78it/s, training_loss=0.000]
# Epoch 10:   7%|▋         | 6/88 [00:00<00:06, 12.75it/s, training_loss=0.000]
# Epoch 10:   7%|▋         | 6/88 [00:00<00:06, 12.75it/s, training_loss=0.000]
# Epoch 10:   7%|▋         | 6/88 [00:00<00:06, 12.75it/s, training_loss=0.000]
# Epoch 10:   9%|▉         | 8/88 [00:00<00:06, 12.72it/s, training_loss=0.000]
# Epoch 10:   9%|▉         | 8/88 [00:00<00:06, 12.72it/s, training_loss=0.000]
# Epoch 10:   9%|▉         | 8/88 [00:00<00:06, 12.72it/s, training_loss=0.000]
# Epoch 10:  11%|█▏        | 10/88 [00:00<00:06, 12.67it/s, training_loss=0.000]
# Epoch 10:  11%|█▏        | 10/88 [00:00<00:06, 12.67it/s, training_loss=0.000]
# Epoch 10:  11%|█▏        | 10/88 [00:00<00:06, 12.67it/s, training_loss=0.000]
# Epoch 10:  14%|█▎        | 12/88 [00:00<00:06, 12.62it/s, training_loss=0.000]
# Epoch 10:  14%|█▎        | 12/88 [00:01<00:06, 12.62it/s, training_loss=0.000]
# Epoch 10:  14%|█▎        | 12/88 [00:01<00:06, 12.62it/s, training_loss=0.000]
# Epoch 10:  16%|█▌        | 14/88 [00:01<00:05, 12.57it/s, training_loss=0.000]
# Epoch 10:  16%|█▌        | 14/88 [00:01<00:05, 12.57it/s, training_loss=0.000]
# Epoch 10:  16%|█▌        | 14/88 [00:01<00:05, 12.57it/s, training_loss=0.000]
# Epoch 10:  18%|█▊        | 16/88 [00:01<00:05, 12.56it/s, training_loss=0.000]
# Epoch 10:  18%|█▊        | 16/88 [00:01<00:05, 12.56it/s, training_loss=0.000]
# Epoch 10:  18%|█▊        | 16/88 [00:01<00:05, 12.56it/s, training_loss=0.000]
# Epoch 10:  20%|██        | 18/88 [00:01<00:05, 12.54it/s, training_loss=0.000]
# Epoch 10:  20%|██        | 18/88 [00:01<00:05, 12.54it/s, training_loss=0.000]
# Epoch 10:  20%|██        | 18/88 [00:01<00:05, 12.54it/s, training_loss=0.000]
# Epoch 10:  23%|██▎       | 20/88 [00:01<00:05, 12.59it/s, training_loss=0.000]
# Epoch 10:  23%|██▎       | 20/88 [00:01<00:05, 12.59it/s, training_loss=0.000]
# Epoch 10:  23%|██▎       | 20/88 [00:01<00:05, 12.59it/s, training_loss=0.000]
# Epoch 10:  25%|██▌       | 22/88 [00:01<00:05, 12.65it/s, training_loss=0.000]
# Epoch 10:  25%|██▌       | 22/88 [00:01<00:05, 12.65it/s, training_loss=0.000]
# Epoch 10:  25%|██▌       | 22/88 [00:01<00:05, 12.65it/s, training_loss=0.000]
# Epoch 10:  27%|██▋       | 24/88 [00:01<00:05, 12.71it/s, training_loss=0.000]
# Epoch 10:  27%|██▋       | 24/88 [00:01<00:05, 12.71it/s, training_loss=0.000]
# Epoch 10:  27%|██▋       | 24/88 [00:02<00:05, 12.71it/s, training_loss=0.000]
# Epoch 10:  30%|██▉       | 26/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  30%|██▉       | 26/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  30%|██▉       | 26/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  32%|███▏      | 28/88 [00:02<00:04, 12.78it/s, training_loss=0.000]
# Epoch 10:  32%|███▏      | 28/88 [00:02<00:04, 12.78it/s, training_loss=0.000]
# Epoch 10:  32%|███▏      | 28/88 [00:02<00:04, 12.78it/s, training_loss=0.000]
# Epoch 10:  34%|███▍      | 30/88 [00:02<00:04, 12.78it/s, training_loss=0.000]
# Epoch 10:  34%|███▍      | 30/88 [00:02<00:04, 12.78it/s, training_loss=0.000]
# Epoch 10:  34%|███▍      | 30/88 [00:02<00:04, 12.78it/s, training_loss=0.000]
# Epoch 10:  36%|███▋      | 32/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  36%|███▋      | 32/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  36%|███▋      | 32/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  39%|███▊      | 34/88 [00:02<00:04, 12.72it/s, training_loss=0.000]
# Epoch 10:  39%|███▊      | 34/88 [00:02<00:04, 12.72it/s, training_loss=0.000]
# Epoch 10:  39%|███▊      | 34/88 [00:02<00:04, 12.72it/s, training_loss=0.000]
# Epoch 10:  41%|████      | 36/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  41%|████      | 36/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  41%|████      | 36/88 [00:02<00:04, 12.74it/s, training_loss=0.000]
# Epoch 10:  43%|████▎     | 38/88 [00:02<00:03, 12.80it/s, training_loss=0.000]
# Epoch 10:  43%|████▎     | 38/88 [00:03<00:03, 12.80it/s, training_loss=0.000]
# Epoch 10:  43%|████▎     | 38/88 [00:03<00:03, 12.80it/s, training_loss=0.000]
# Epoch 10:  45%|████▌     | 40/88 [00:03<00:03, 12.79it/s, training_loss=0.000]
# Epoch 10:  45%|████▌     | 40/88 [00:03<00:03, 12.79it/s, training_loss=0.000]
# Epoch 10:  45%|████▌     | 40/88 [00:03<00:03, 12.79it/s, training_loss=0.000]
# Epoch 10:  48%|████▊     | 42/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 10:  48%|████▊     | 42/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 10:  48%|████▊     | 42/88 [00:03<00:03, 12.78it/s, training_loss=0.000]
# Epoch 10:  50%|█████     | 44/88 [00:03<00:03, 12.75it/s, training_loss=0.000]
# Epoch 10:  50%|█████     | 44/88 [00:03<00:03, 12.75it/s, training_loss=0.000]
# Epoch 10:  50%|█████     | 44/88 [00:03<00:03, 12.75it/s, training_loss=0.000]
# Epoch 10:  52%|█████▏    | 46/88 [00:03<00:03, 12.68it/s, training_loss=0.000]
# Epoch 10:  52%|█████▏    | 46/88 [00:03<00:03, 12.68it/s, training_loss=0.000]
# Epoch 10:  52%|█████▏    | 46/88 [00:03<00:03, 12.68it/s, training_loss=0.000]
# Epoch 10:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.000]
# Epoch 10:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.000]
# Epoch 10:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.000]
# Epoch 10:  57%|█████▋    | 50/88 [00:03<00:03, 12.56it/s, training_loss=0.000]
# Epoch 10:  57%|█████▋    | 50/88 [00:04<00:03, 12.56it/s, training_loss=0.000]
# Epoch 10:  57%|█████▋    | 50/88 [00:04<00:03, 12.56it/s, training_loss=0.000]
# Epoch 10:  59%|█████▉    | 52/88 [00:04<00:02, 12.54it/s, training_loss=0.000]
# Epoch 10:  59%|█████▉    | 52/88 [00:04<00:02, 12.54it/s, training_loss=0.000]
# Epoch 10:  84%|████████▍ | 74/88 [00:05<00:01, 12.46it/s, training_loss=0.000]
# Epoch 10:  84%|████████▍ | 74/88 [00:05<00:01, 12.46it/s, training_loss=0.000]
# Epoch 10:  84%|████████▍ | 74/88 [00:06<00:01, 12.46it/s, training_loss=0.000]
# Epoch 10:  86%|████████▋ | 76/88 [00:06<00:00, 12.50it/s, training_loss=0.000]
# Epoch 10:  86%|████████▋ | 76/88 [00:06<00:00, 12.50it/s, training_loss=0.000]
# Epoch 10:  86%|████████▋ | 76/88 [00:06<00:00, 12.50it/s, training_loss=0.000]
# Epoch 10:  89%|████████▊ | 78/88 [00:06<00:00, 12.52it/s, training_loss=0.000]
# Epoch 10:  89%|████████▊ | 78/88 [00:06<00:00, 12.52it/s, training_loss=0.000]
# Epoch 10:  89%|████████▊ | 78/88 [00:06<00:00, 12.52it/s, training_loss=0.000]
# Epoch 10:  91%|█████████ | 80/88 [00:06<00:00, 12.53it/s, training_loss=0.000]
# Epoch 10:  91%|█████████ | 80/88 [00:06<00:00, 12.53it/s, training_loss=0.000]
# Epoch 10:  91%|█████████ | 80/88 [00:06<00:00, 12.53it/s, training_loss=0.000]
# Epoch 10:  93%|█████████▎| 82/88 [00:06<00:00, 12.49it/s, training_loss=0.000]
# Epoch 10:  93%|█████████▎| 82/88 [00:06<00:00, 12.49it/s, training_loss=0.000]
# Epoch 10:  93%|█████████▎| 82/88 [00:06<00:00, 12.49it/s, training_loss=0.000]
# Epoch 10:  95%|█████████▌| 84/88 [00:06<00:00, 12.47it/s, training_loss=0.000]
# Epoch 10:  95%|█████████▌| 84/88 [00:06<00:00, 12.47it/s, training_loss=0.000]
# Epoch 10:  95%|█████████▌| 84/88 [00:06<00:00, 12.47it/s, training_loss=0.000]
# Epoch 10:  98%|█████████▊| 86/88 [00:06<00:00, 12.52it/s, training_loss=0.000]
# Epoch 10:  98%|█████████▊| 86/88 [00:06<00:00, 12.52it/s, training_loss=0.000]
# Epoch 10:  98%|█████████▊| 86/88 [00:06<00:00, 12.52it/s, training_loss=0.000]
# Epoch 10: 100%|██████████| 88/88 [00:06<00:00, 12.58it/s, training_loss=0.000]
# 100%|██████████| 10/10 [01:17<00:00,  7.74s/it]
# Epoch 10
# Training loss: 0.0003215950610782866

# %%
##Optional, when I am uploading th emodel
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('/content/finetuned_BERT_epoch_2.model', map_location=torch.device('cpu')))
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# <All keys matched successfully>

# %%
_, predictions, true_vals = evaluate(dataloader_validation)

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88        88
#            1       0.87      0.91      0.89        87
#
#     accuracy                           0.89       175
#    macro avg       0.89      0.89      0.89       175
# weighted avg       0.89      0.89      0.89       175
#
# Overall accuracy: 0.8857142857142857
# F1 macro       : 0.8856806898353802

# %%
predictions[:3]
# Out:
# array([[ 0.43597564, -0.8802067 ],
#        [ 1.647924  , -1.6333351 ],
#        [-1.7186362 ,  1.7910877 ]], dtype=float32)

# %% [markdown]
# ## Finetuning SciBERT

# %%
model = BertForSequenceClassification.from_pretrained("allenai/scibert_scivocab_uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: allenai/scibert_scivocab_uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
import random

seed_val = 0
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):

    model.eval()

    loss_val_total = 0
    predictions, true_vals = [], []

    for batch in dataloader_val:

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():
            outputs = model(**inputs)

        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)

    loss_val_avg = loss_val_total/len(dataloader_val)

    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)

    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):

    model.train()

    loss_train_total = 0

    progress_bar = tqdm(dataloader_train, desc='Epoch {:1d}'.format(epoch), leave=False, disable=False)
    for batch in progress_bar:

        model.zero_grad()

        batch = tuple(b.to(device) for b in batch)

        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        outputs = model(**inputs)

        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        optimizer.step()
        scheduler.step()

        progress_bar.set_postfix({'training_loss': '{:.3f}'.format(loss.item()/len(batch))})


    torch.save(model.state_dict(), f'finetuned_SciBERT_epoch_{epoch}.model')

    tqdm.write(f'\nEpoch {epoch}')

    loss_train_avg = loss_train_total/len(dataloader_train)
    tqdm.write(f'Training loss: {loss_train_avg}')

    # val_loss, predictions, true_vals = evaluate(dataloader_validation)
    # val_f1 = f1_score_func(predictions, true_vals)
    # tqdm.write(f'Validation loss: {val_loss}')
    # tqdm.write(f'F1 Score (Weighted): {val_f1}')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.244]
# Epoch 1:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.276]
# Epoch 1:   2%|▏         | 2/88 [00:00<00:07, 11.73it/s, training_loss=0.276]
# Epoch 1:   2%|▏         | 2/88 [00:00<00:07, 11.73it/s, training_loss=0.260]
# Epoch 1:   2%|▏         | 2/88 [00:00<00:07, 11.73it/s, training_loss=0.224]
# Epoch 1:   5%|▍         | 4/88 [00:00<00:06, 12.09it/s, training_loss=0.224]
# Epoch 1:   5%|▍         | 4/88 [00:00<00:06, 12.09it/s, training_loss=0.235]
# Epoch 1:   5%|▍         | 4/88 [00:00<00:06, 12.09it/s, training_loss=0.192]
# Epoch 1:   7%|▋         | 6/88 [00:00<00:06, 12.23it/s, training_loss=0.192]
# Epoch 1:   7%|▋         | 6/88 [00:00<00:06, 12.23it/s, training_loss=0.244]
# Epoch 1:   7%|▋         | 6/88 [00:00<00:06, 12.23it/s, training_loss=0.216]
# Epoch 1:   9%|▉         | 8/88 [00:00<00:06, 12.31it/s, training_loss=0.216]
# Epoch 1:   9%|▉         | 8/88 [00:00<00:06, 12.31it/s, training_loss=0.237]
# Epoch 1:   9%|▉         | 8/88 [00:00<00:06, 12.31it/s, training_loss=0.204]
# Epoch 1:  11%|█▏        | 10/88 [00:00<00:06, 12.36it/s, training_loss=0.204]
# Epoch 1:  11%|█▏        | 10/88 [00:00<00:06, 12.36it/s, training_loss=0.267]
# Epoch 1:  11%|█▏        | 10/88 [00:00<00:06, 12.36it/s, training_loss=0.265]
# Epoch 1:  14%|█▎        | 12/88 [00:00<00:06, 12.39it/s, training_loss=0.265]
# Epoch 1:  14%|█▎        | 12/88 [00:01<00:06, 12.39it/s, training_loss=0.278]
# Epoch 1:  14%|█▎        | 12/88 [00:01<00:06, 12.39it/s, training_loss=0.220]
# Epoch 1:  16%|█▌        | 14/88 [00:01<00:05, 12.40it/s, training_loss=0.220]
# Epoch 1:  16%|█▌        | 14/88 [00:01<00:05, 12.40it/s, training_loss=0.262]
# Epoch 1:  16%|█▌        | 14/88 [00:01<00:05, 12.40it/s, training_loss=0.247]
# Epoch 1:  18%|█▊        | 16/88 [00:01<00:05, 12.43it/s, training_loss=0.247]
# Epoch 1:  89%|████████▊ | 78/88 [00:06<00:00, 12.63it/s, training_loss=0.262]
# Epoch 1:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.262]
# Epoch 1:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.248]
# Epoch 1:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.260]
# Epoch 1:  93%|█████████▎| 82/88 [00:06<00:00, 12.62it/s, training_loss=0.260]
# Epoch 1:  93%|█████████▎| 82/88 [00:06<00:00, 12.62it/s, training_loss=0.209]
# Epoch 1:  93%|█████████▎| 82/88 [00:06<00:00, 12.62it/s, training_loss=0.266]
# Epoch 1:  95%|█████████▌| 84/88 [00:06<00:00, 12.63it/s, training_loss=0.266]
# Epoch 1:  95%|█████████▌| 84/88 [00:06<00:00, 12.63it/s, training_loss=0.258]
# Epoch 1:  95%|█████████▌| 84/88 [00:06<00:00, 12.63it/s, training_loss=0.241]
# Epoch 1:  98%|█████████▊| 86/88 [00:06<00:00, 12.63it/s, training_loss=0.241]
# Epoch 1:  98%|█████████▊| 86/88 [00:06<00:00, 12.63it/s, training_loss=0.249]
# Epoch 1:  98%|█████████▊| 86/88 [00:07<00:00, 12.63it/s, training_loss=0.174]
# Epoch 1: 100%|██████████| 88/88 [00:07<00:00, 12.66it/s, training_loss=0.174]
#  10%|█         | 1/10 [00:07<01:07,  7.52s/it]
# Epoch 1
# Training loss: 0.7129781232638792
# Epoch 2:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 2:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.254]
# Epoch 2:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.220]
# Epoch 2:   2%|▏         | 2/88 [00:00<00:06, 12.71it/s, training_loss=0.220]
# Epoch 2:   2%|▏         | 2/88 [00:00<00:06, 12.71it/s, training_loss=0.253]
# Epoch 2:   2%|▏         | 2/88 [00:00<00:06, 12.71it/s, training_loss=0.240]
# Epoch 2:   5%|▍         | 4/88 [00:00<00:06, 12.67it/s, training_loss=0.240]
# Epoch 2:   5%|▍         | 4/88 [00:00<00:06, 12.67it/s, training_loss=0.227]
# Epoch 2:   5%|▍         | 4/88 [00:00<00:06, 12.67it/s, training_loss=0.252]
# Epoch 2:   7%|▋         | 6/88 [00:00<00:06, 12.61it/s, training_loss=0.252]
# Epoch 2:   7%|▋         | 6/88 [00:00<00:06, 12.61it/s, training_loss=0.264]
# Epoch 2:   7%|▋         | 6/88 [00:00<00:06, 12.61it/s, training_loss=0.250]
# Epoch 2:   9%|▉         | 8/88 [00:00<00:06, 12.69it/s, training_loss=0.250]
# Epoch 2:   9%|▉         | 8/88 [00:00<00:06, 12.69it/s, training_loss=0.258]
# Epoch 2:   9%|▉         | 8/88 [00:00<00:06, 12.69it/s, training_loss=0.243]
# Epoch 2:  11%|█▏        | 10/88 [00:00<00:06, 12.62it/s, training_loss=0.243]
# Epoch 2:  11%|█▏        | 10/88 [00:00<00:06, 12.62it/s, training_loss=0.173]
# Epoch 2:  36%|███▋      | 32/88 [00:02<00:04, 12.53it/s, training_loss=0.232]
# Epoch 2:  36%|███▋      | 32/88 [00:02<00:04, 12.53it/s, training_loss=0.217]
# Epoch 2:  36%|███▋      | 32/88 [00:02<00:04, 12.53it/s, training_loss=0.227]
# Epoch 2:  39%|███▊      | 34/88 [00:02<00:04, 12.53it/s, training_loss=0.227]
# Epoch 2:  39%|███▊      | 34/88 [00:02<00:04, 12.53it/s, training_loss=0.202]
# Epoch 2:  39%|███▊      | 34/88 [00:02<00:04, 12.53it/s, training_loss=0.221]
# Epoch 2:  41%|████      | 36/88 [00:02<00:04, 12.54it/s, training_loss=0.221]
# Epoch 2:  41%|████      | 36/88 [00:02<00:04, 12.54it/s, training_loss=0.230]
# Epoch 2:  41%|████      | 36/88 [00:03<00:04, 12.54it/s, training_loss=0.206]
# Epoch 2:  43%|████▎     | 38/88 [00:03<00:03, 12.51it/s, training_loss=0.206]
# Epoch 2:  43%|████▎     | 38/88 [00:03<00:03, 12.51it/s, training_loss=0.232]
# Epoch 2:  43%|████▎     | 38/88 [00:03<00:03, 12.51it/s, training_loss=0.222]
# Epoch 2:  45%|████▌     | 40/88 [00:03<00:03, 12.51it/s, training_loss=0.222]
# Epoch 2:  45%|████▌     | 40/88 [00:03<00:03, 12.51it/s, training_loss=0.213]
# Epoch 2:  45%|████▌     | 40/88 [00:03<00:03, 12.51it/s, training_loss=0.197]
# Epoch 2:  48%|████▊     | 42/88 [00:03<00:03, 12.50it/s, training_loss=0.197]
# Epoch 2:  48%|████▊     | 42/88 [00:03<00:03, 12.50it/s, training_loss=0.268]
# Epoch 2:  48%|████▊     | 42/88 [00:03<00:03, 12.50it/s, training_loss=0.236]
# Epoch 2:  50%|█████     | 44/88 [00:03<00:03, 12.51it/s, training_loss=0.236]
# Epoch 2:  50%|█████     | 44/88 [00:03<00:03, 12.51it/s, training_loss=0.218]
# Epoch 2:  50%|█████     | 44/88 [00:03<00:03, 12.51it/s, training_loss=0.264]
# Epoch 2:  52%|█████▏    | 46/88 [00:03<00:03, 12.54it/s, training_loss=0.264]
# Epoch 2:  52%|█████▏    | 46/88 [00:03<00:03, 12.54it/s, training_loss=0.247]
# Epoch 2:  52%|█████▏    | 46/88 [00:03<00:03, 12.54it/s, training_loss=0.245]
# Epoch 2:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.245]
# Epoch 2:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.236]
# Epoch 2:  55%|█████▍    | 48/88 [00:03<00:03, 12.55it/s, training_loss=0.231]
# Epoch 2:  57%|█████▋    | 50/88 [00:03<00:03, 12.56it/s, training_loss=0.231]
# Epoch 2:  57%|█████▋    | 50/88 [00:04<00:03, 12.56it/s, training_loss=0.257]
# Epoch 2:  57%|█████▋    | 50/88 [00:04<00:03, 12.56it/s, training_loss=0.211]
# Epoch 2:  59%|█████▉    | 52/88 [00:04<00:02, 12.59it/s, training_loss=0.211]
# Epoch 2:  82%|████████▏ | 72/88 [00:05<00:01, 12.62it/s, training_loss=0.233]
# Epoch 2:  84%|████████▍ | 74/88 [00:05<00:01, 12.57it/s, training_loss=0.233]
# Epoch 2:  84%|████████▍ | 74/88 [00:05<00:01, 12.57it/s, training_loss=0.269]
# Epoch 2:  84%|████████▍ | 74/88 [00:06<00:01, 12.57it/s, training_loss=0.255]
# Epoch 2:  86%|████████▋ | 76/88 [00:06<00:00, 12.42it/s, training_loss=0.255]
# Epoch 2:  86%|████████▋ | 76/88 [00:06<00:00, 12.42it/s, training_loss=0.226]
# Epoch 2:  86%|████████▋ | 76/88 [00:06<00:00, 12.42it/s, training_loss=0.252]
# Epoch 2:  89%|████████▊ | 78/88 [00:06<00:00, 12.52it/s, training_loss=0.252]
# Epoch 2:  89%|████████▊ | 78/88 [00:06<00:00, 12.52it/s, training_loss=0.257]
# Epoch 2:  89%|████████▊ | 78/88 [00:06<00:00, 12.52it/s, training_loss=0.219]
# Epoch 2:  91%|█████████ | 80/88 [00:06<00:00, 12.54it/s, training_loss=0.219]
# Epoch 2:  91%|█████████ | 80/88 [00:06<00:00, 12.54it/s, training_loss=0.247]
# Epoch 2:  91%|█████████ | 80/88 [00:06<00:00, 12.54it/s, training_loss=0.235]
# Epoch 2:  93%|█████████▎| 82/88 [00:06<00:00, 12.57it/s, training_loss=0.235]
# Epoch 2:  93%|█████████▎| 82/88 [00:06<00:00, 12.57it/s, training_loss=0.253]
# Epoch 2:  93%|█████████▎| 82/88 [00:06<00:00, 12.57it/s, training_loss=0.245]
# Epoch 2:  95%|█████████▌| 84/88 [00:06<00:00, 12.62it/s, training_loss=0.245]
# Epoch 2:  95%|█████████▌| 84/88 [00:06<00:00, 12.62it/s, training_loss=0.239]
# Epoch 2:  95%|█████████▌| 84/88 [00:06<00:00, 12.62it/s, training_loss=0.299]
# Epoch 2:  98%|█████████▊| 86/88 [00:06<00:00, 12.66it/s, training_loss=0.299]
# Epoch 2:  98%|█████████▊| 86/88 [00:06<00:00, 12.66it/s, training_loss=0.231]
# Epoch 2:  98%|█████████▊| 86/88 [00:06<00:00, 12.66it/s, training_loss=0.203]
# Epoch 2: 100%|██████████| 88/88 [00:06<00:00, 12.79it/s, training_loss=0.203]
#  20%|██        | 2/10 [00:15<01:00,  7.54s/it]
# Epoch 2
# Training loss: 0.7101707214658911
# Epoch 3:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 3:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.262]
# Epoch 3:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.256]
# Epoch 3:   2%|▏         | 2/88 [00:00<00:06, 12.76it/s, training_loss=0.256]
# Epoch 3:   2%|▏         | 2/88 [00:00<00:06, 12.76it/s, training_loss=0.239]
# Epoch 3:   2%|▏         | 2/88 [00:00<00:06, 12.76it/s, training_loss=0.247]
# Epoch 3:   5%|▍         | 4/88 [00:00<00:06, 12.59it/s, training_loss=0.247]
# Epoch 3:   5%|▍         | 4/88 [00:00<00:06, 12.59it/s, training_loss=0.242]
# Epoch 3:   5%|▍         | 4/88 [00:00<00:06, 12.59it/s, training_loss=0.248]
# Epoch 3:   7%|▋         | 6/88 [00:00<00:06, 12.57it/s, training_loss=0.248]
# Epoch 3:   7%|▋         | 6/88 [00:00<00:06, 12.57it/s, training_loss=0.249]
# Epoch 3:   7%|▋         | 6/88 [00:00<00:06, 12.57it/s, training_loss=0.255]
# Epoch 3:   9%|▉         | 8/88 [00:00<00:06, 12.38it/s, training_loss=0.255]
# Epoch 3:   9%|▉         | 8/88 [00:00<00:06, 12.38it/s, training_loss=0.269]
# Epoch 3:   9%|▉         | 8/88 [00:00<00:06, 12.38it/s, training_loss=0.218]
# Epoch 3:  11%|█▏        | 10/88 [00:00<00:06, 12.43it/s, training_loss=0.218]
# Epoch 3:  11%|█▏        | 10/88 [00:00<00:06, 12.43it/s, training_loss=0.242]
# Epoch 3:  11%|█▏        | 10/88 [00:00<00:06, 12.43it/s, training_loss=0.217]
# Epoch 3:  14%|█▎        | 12/88 [00:00<00:06, 12.41it/s, training_loss=0.217]
# Epoch 3:  14%|█▎        | 12/88 [00:01<00:06, 12.41it/s, training_loss=0.235]
# Epoch 3:  14%|█▎        | 12/88 [00:01<00:06, 12.41it/s, training_loss=0.223]
# Epoch 3:  16%|█▌        | 14/88 [00:01<00:05, 12.37it/s, training_loss=0.223]
# Epoch 3:  16%|█▌        | 14/88 [00:01<00:05, 12.37it/s, training_loss=0.232]
# Epoch 3:  16%|█▌        | 14/88 [00:01<00:05, 12.37it/s, training_loss=0.201]
# Epoch 3:  18%|█▊        | 16/88 [00:01<00:05, 12.38it/s, training_loss=0.201]
# Epoch 3:  18%|█▊        | 16/88 [00:01<00:05, 12.38it/s, training_loss=0.244]
# Epoch 3:  18%|█▊        | 16/88 [00:01<00:05, 12.38it/s, training_loss=0.242]
# Epoch 3:  20%|██        | 18/88 [00:01<00:05, 12.42it/s, training_loss=0.242]
# Epoch 3:  20%|██        | 18/88 [00:01<00:05, 12.42it/s, training_loss=0.234]
# Epoch 3:  20%|██        | 18/88 [00:01<00:05, 12.42it/s, training_loss=0.257]
# Epoch 3:  23%|██▎       | 20/88 [00:01<00:05, 12.10it/s, training_loss=0.257]
# Epoch 3:  23%|██▎       | 20/88 [00:01<00:05, 12.10it/s, training_loss=0.247]
# Epoch 3:  23%|██▎       | 20/88 [00:01<00:05, 12.10it/s, training_loss=0.258]
# Epoch 3:  25%|██▌       | 22/88 [00:01<00:05, 12.16it/s, training_loss=0.258]
# Epoch 3:  25%|██▌       | 22/88 [00:01<00:05, 12.16it/s, training_loss=0.233]
# Epoch 3:  25%|██▌       | 22/88 [00:01<00:05, 12.16it/s, training_loss=0.245]
# Epoch 3:  27%|██▋       | 24/88 [00:01<00:05, 12.24it/s, training_loss=0.245]
# Epoch 3:  27%|██▋       | 24/88 [00:02<00:05, 12.24it/s, training_loss=0.212]
# Epoch 3:  27%|██▋       | 24/88 [00:02<00:05, 12.24it/s, training_loss=0.234]
# Epoch 3:  30%|██▉       | 26/88 [00:02<00:05, 12.24it/s, training_loss=0.234]
# Epoch 3:  30%|██▉       | 26/88 [00:02<00:05, 12.24it/s, training_loss=0.236]
# Epoch 3:  30%|██▉       | 26/88 [00:02<00:05, 12.24it/s, training_loss=0.180]
# Epoch 3:  32%|███▏      | 28/88 [00:02<00:04, 12.27it/s, training_loss=0.180]
# Epoch 3:  32%|███▏      | 28/88 [00:02<00:04, 12.27it/s, training_loss=0.237]
# Epoch 3:  32%|███▏      | 28/88 [00:02<00:04, 12.27it/s, training_loss=0.264]
# Epoch 3:  34%|███▍      | 30/88 [00:02<00:04, 12.14it/s, training_loss=0.264]
# Epoch 3:  34%|███▍      | 30/88 [00:02<00:04, 12.14it/s, training_loss=0.242]
# Epoch 3:  34%|███▍      | 30/88 [00:02<00:04, 12.14it/s, training_loss=0.197]
# Epoch 3:  36%|███▋      | 32/88 [00:02<00:04, 12.16it/s, training_loss=0.197]
# Epoch 3:  36%|███▋      | 32/88 [00:02<00:04, 12.16it/s, training_loss=0.229]
# Epoch 3:  36%|███▋      | 32/88 [00:02<00:04, 12.16it/s, training_loss=0.175]
# Epoch 3:  39%|███▊      | 34/88 [00:02<00:04, 12.24it/s, training_loss=0.175]
# Epoch 3:  39%|███▊      | 34/88 [00:02<00:04, 12.24it/s, training_loss=0.266]
# Epoch 3:  39%|███▊      | 34/88 [00:02<00:04, 12.24it/s, training_loss=0.247]
# Epoch 3:  41%|████      | 36/88 [00:02<00:04, 12.30it/s, training_loss=0.247]
# Epoch 3:  41%|████      | 36/88 [00:03<00:04, 12.30it/s, training_loss=0.242]
# Epoch 3:  41%|████      | 36/88 [00:03<00:04, 12.30it/s, training_loss=0.247]
# Epoch 3:  43%|████▎     | 38/88 [00:03<00:04, 12.32it/s, training_loss=0.247]
# Epoch 3:  43%|████▎     | 38/88 [00:03<00:04, 12.32it/s, training_loss=0.245]
# Epoch 3:  43%|████▎     | 38/88 [00:03<00:04, 12.32it/s, training_loss=0.233]
# Epoch 3:  45%|████▌     | 40/88 [00:03<00:03, 12.36it/s, training_loss=0.233]
# Epoch 3:  45%|████▌     | 40/88 [00:03<00:03, 12.36it/s, training_loss=0.224]
# Epoch 3:  45%|████▌     | 40/88 [00:03<00:03, 12.36it/s, training_loss=0.223]
# Epoch 3:  48%|████▊     | 42/88 [00:03<00:03, 12.37it/s, training_loss=0.223]
# Epoch 3:  48%|████▊     | 42/88 [00:03<00:03, 12.37it/s, training_loss=0.221]
# Epoch 3:  48%|████▊     | 42/88 [00:03<00:03, 12.37it/s, training_loss=0.249]
# Epoch 3:  50%|█████     | 44/88 [00:03<00:03, 12.35it/s, training_loss=0.249]
# Epoch 3:  50%|█████     | 44/88 [00:03<00:03, 12.35it/s, training_loss=0.335]
# Epoch 3:  50%|█████     | 44/88 [00:03<00:03, 12.35it/s, training_loss=0.226]
# Epoch 3:  52%|█████▏    | 46/88 [00:03<00:03, 12.34it/s, training_loss=0.226]
# Epoch 3:  52%|█████▏    | 46/88 [00:03<00:03, 12.34it/s, training_loss=0.225]
# Epoch 3:  52%|█████▏    | 46/88 [00:03<00:03, 12.34it/s, training_loss=0.235]
# Epoch 3:  55%|█████▍    | 48/88 [00:03<00:03, 12.17it/s, training_loss=0.235]
# Epoch 3:  55%|█████▍    | 48/88 [00:03<00:03, 12.17it/s, training_loss=0.238]
# Epoch 3:  55%|█████▍    | 48/88 [00:04<00:03, 12.17it/s, training_loss=0.222]
# Epoch 3:  57%|█████▋    | 50/88 [00:04<00:03, 12.13it/s, training_loss=0.222]
# Epoch 3:  57%|█████▋    | 50/88 [00:04<00:03, 12.13it/s, training_loss=0.251]
# Epoch 3:  57%|█████▋    | 50/88 [00:04<00:03, 12.13it/s, training_loss=0.255]
# Epoch 3:  59%|█████▉    | 52/88 [00:04<00:02, 12.02it/s, training_loss=0.255]
# Epoch 3:  59%|█████▉    | 52/88 [00:04<00:02, 12.02it/s, training_loss=0.247]
# Epoch 3:  59%|█████▉    | 52/88 [00:04<00:02, 12.02it/s, training_loss=0.237]
# Epoch 3:  61%|██████▏   | 54/88 [00:04<00:02, 12.01it/s, training_loss=0.237]
# Epoch 3:  61%|██████▏   | 54/88 [00:04<00:02, 12.01it/s, training_loss=0.224]
# Epoch 3:  61%|██████▏   | 54/88 [00:04<00:02, 12.01it/s, training_loss=0.214]
# Epoch 3:  64%|██████▎   | 56/88 [00:04<00:02, 12.19it/s, training_loss=0.214]
# Epoch 3:  64%|██████▎   | 56/88 [00:04<00:02, 12.19it/s, training_loss=0.235]
# Epoch 3:  64%|██████▎   | 56/88 [00:04<00:02, 12.19it/s, training_loss=0.217]
# Epoch 3:  66%|██████▌   | 58/88 [00:04<00:02, 12.34it/s, training_loss=0.217]
# Epoch 3:  66%|██████▌   | 58/88 [00:04<00:02, 12.34it/s, training_loss=0.231]
# Epoch 3:  66%|██████▌   | 58/88 [00:04<00:02, 12.34it/s, training_loss=0.227]
# Epoch 3:  68%|██████▊   | 60/88 [00:04<00:02, 12.39it/s, training_loss=0.227]
# Epoch 3:  68%|██████▊   | 60/88 [00:04<00:02, 12.39it/s, training_loss=0.208]
# Epoch 3:  68%|██████▊   | 60/88 [00:05<00:02, 12.39it/s, training_loss=0.280]
# Epoch 3:  70%|███████   | 62/88 [00:05<00:02, 12.40it/s, training_loss=0.280]
# Epoch 3:  70%|███████   | 62/88 [00:05<00:02, 12.40it/s, training_loss=0.220]
# Epoch 3:  70%|███████   | 62/88 [00:05<00:02, 12.40it/s, training_loss=0.207]
# Epoch 3:  73%|███████▎  | 64/88 [00:05<00:01, 12.47it/s, training_loss=0.207]
# Epoch 3:  73%|███████▎  | 64/88 [00:05<00:01, 12.47it/s, training_loss=0.218]
# Epoch 3:  73%|███████▎  | 64/88 [00:05<00:01, 12.47it/s, training_loss=0.275]
# Epoch 3:  75%|███████▌  | 66/88 [00:05<00:01, 12.51it/s, training_loss=0.275]
# Epoch 3:  75%|███████▌  | 66/88 [00:05<00:01, 12.51it/s, training_loss=0.231]
# Epoch 3:  75%|███████▌  | 66/88 [00:05<00:01, 12.51it/s, training_loss=0.243]
# Epoch 3:  77%|███████▋  | 68/88 [00:05<00:01, 12.50it/s, training_loss=0.243]
# Epoch 3:  77%|███████▋  | 68/88 [00:05<00:01, 12.50it/s, training_loss=0.246]
# Epoch 3:  77%|███████▋  | 68/88 [00:05<00:01, 12.50it/s, training_loss=0.265]
# Epoch 3:  80%|███████▉  | 70/88 [00:05<00:01, 12.45it/s, training_loss=0.265]
# Epoch 3:  80%|███████▉  | 70/88 [00:05<00:01, 12.45it/s, training_loss=0.245]
# Epoch 3:  80%|███████▉  | 70/88 [00:05<00:01, 12.45it/s, training_loss=0.279]
# Epoch 3:  82%|████████▏ | 72/88 [00:05<00:01, 12.44it/s, training_loss=0.279]
# Epoch 3:  82%|████████▏ | 72/88 [00:05<00:01, 12.44it/s, training_loss=0.235]
# Epoch 3:  82%|████████▏ | 72/88 [00:06<00:01, 12.44it/s, training_loss=0.216]
# Epoch 3:  84%|████████▍ | 74/88 [00:06<00:01, 12.48it/s, training_loss=0.216]
# Epoch 3:  84%|████████▍ | 74/88 [00:06<00:01, 12.48it/s, training_loss=0.210]
# Epoch 3:  84%|████████▍ | 74/88 [00:06<00:01, 12.48it/s, training_loss=0.231]
# Epoch 3:  86%|████████▋ | 76/88 [00:06<00:00, 12.50it/s, training_loss=0.231]
# Epoch 3:  86%|████████▋ | 76/88 [00:06<00:00, 12.50it/s, training_loss=0.211]
# Epoch 3:  86%|████████▋ | 76/88 [00:06<00:00, 12.50it/s, training_loss=0.219]
# Epoch 3:  89%|████████▊ | 78/88 [00:06<00:00, 12.47it/s, training_loss=0.219]
# Epoch 3:  89%|████████▊ | 78/88 [00:06<00:00, 12.47it/s, training_loss=0.266]
# Epoch 3:  89%|████████▊ | 78/88 [00:06<00:00, 12.47it/s, training_loss=0.221]
# Epoch 3:  91%|█████████ | 80/88 [00:06<00:00, 12.51it/s, training_loss=0.221]
# Epoch 3:  91%|█████████ | 80/88 [00:06<00:00, 12.51it/s, training_loss=0.236]
# Epoch 3:  91%|█████████ | 80/88 [00:06<00:00, 12.51it/s, training_loss=0.218]
# Epoch 3:  93%|█████████▎| 82/88 [00:06<00:00, 12.29it/s, training_loss=0.218]
# Epoch 3:  93%|█████████▎| 82/88 [00:06<00:00, 12.29it/s, training_loss=0.232]
# Epoch 3:  93%|█████████▎| 82/88 [00:06<00:00, 12.29it/s, training_loss=0.241]
# Epoch 3:  95%|█████████▌| 84/88 [00:06<00:00, 12.15it/s, training_loss=0.241]
# Epoch 3:  95%|█████████▌| 84/88 [00:06<00:00, 12.15it/s, training_loss=0.229]
# Epoch 3:  95%|█████████▌| 84/88 [00:06<00:00, 12.15it/s, training_loss=0.222]
# Epoch 3:  98%|█████████▊| 86/88 [00:06<00:00, 12.23it/s, training_loss=0.222]
# Epoch 3:  98%|█████████▊| 86/88 [00:07<00:00, 12.23it/s, training_loss=0.272]
# Epoch 3:  98%|█████████▊| 86/88 [00:07<00:00, 12.23it/s, training_loss=0.276]
# Epoch 3: 100%|██████████| 88/88 [00:07<00:00, 12.19it/s, training_loss=0.276]
#  30%|███       | 3/10 [00:22<00:53,  7.59s/it]
# Epoch 3
# Training loss: 0.7115101895549081
# Epoch 4:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 4:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.215]
# Epoch 4:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.240]
# Epoch 4:   2%|▏         | 2/88 [00:00<00:07, 11.91it/s, training_loss=0.240]
# Epoch 4:   2%|▏         | 2/88 [00:00<00:07, 11.91it/s, training_loss=0.236]
# Epoch 4:   2%|▏         | 2/88 [00:00<00:07, 11.91it/s, training_loss=0.229]
# Epoch 4:   5%|▍         | 4/88 [00:00<00:06, 12.23it/s, training_loss=0.229]
# Epoch 4:   5%|▍         | 4/88 [00:00<00:06, 12.23it/s, training_loss=0.201]
# Epoch 4:   5%|▍         | 4/88 [00:00<00:06, 12.23it/s, training_loss=0.235]
# Epoch 4:   7%|▋         | 6/88 [00:00<00:06, 12.37it/s, training_loss=0.235]
# Epoch 4:   7%|▋         | 6/88 [00:00<00:06, 12.37it/s, training_loss=0.226]
# Epoch 4:   7%|▋         | 6/88 [00:00<00:06, 12.37it/s, training_loss=0.231]
# Epoch 4:   9%|▉         | 8/88 [00:00<00:06, 12.41it/s, training_loss=0.231]
# Epoch 4:   9%|▉         | 8/88 [00:00<00:06, 12.41it/s, training_loss=0.212]
# Epoch 4:   9%|▉         | 8/88 [00:00<00:06, 12.41it/s, training_loss=0.226]
# Epoch 4:  11%|█▏        | 10/88 [00:00<00:06, 12.42it/s, training_loss=0.226]
# Epoch 4:  11%|█▏        | 10/88 [00:00<00:06, 12.42it/s, training_loss=0.210]
# Epoch 4:  11%|█▏        | 10/88 [00:00<00:06, 12.42it/s, training_loss=0.228]
# Epoch 4:  14%|█▎        | 12/88 [00:00<00:06, 12.42it/s, training_loss=0.228]
# Epoch 4:  14%|█▎        | 12/88 [00:01<00:06, 12.42it/s, training_loss=0.246]
# Epoch 4:  14%|█▎        | 12/88 [00:01<00:06, 12.42it/s, training_loss=0.248]
# Epoch 4:  16%|█▌        | 14/88 [00:01<00:05, 12.40it/s, training_loss=0.248]
# Epoch 4:  16%|█▌        | 14/88 [00:01<00:05, 12.40it/s, training_loss=0.233]
# Epoch 4:  16%|█▌        | 14/88 [00:01<00:05, 12.40it/s, training_loss=0.227]
# Epoch 4:  18%|█▊        | 16/88 [00:01<00:05, 12.39it/s, training_loss=0.227]
# Epoch 4:  18%|█▊        | 16/88 [00:01<00:05, 12.39it/s, training_loss=0.236]
# Epoch 4:  18%|█▊        | 16/88 [00:01<00:05, 12.39it/s, training_loss=0.238]
# Epoch 4:  20%|██        | 18/88 [00:01<00:05, 12.44it/s, training_loss=0.238]
# Epoch 4:  20%|██        | 18/88 [00:01<00:05, 12.44it/s, training_loss=0.239]
# Epoch 4:  20%|██        | 18/88 [00:01<00:05, 12.44it/s, training_loss=0.199]
# Epoch 4:  45%|████▌     | 40/88 [00:03<00:03, 12.65it/s, training_loss=0.256]
# Epoch 4:  48%|████▊     | 42/88 [00:03<00:03, 12.69it/s, training_loss=0.256]
# Epoch 4:  48%|████▊     | 42/88 [00:03<00:03, 12.69it/s, training_loss=0.224]
# Epoch 4:  48%|████▊     | 42/88 [00:03<00:03, 12.69it/s, training_loss=0.255]
# Epoch 4:  50%|█████     | 44/88 [00:03<00:03, 12.72it/s, training_loss=0.255]
# Epoch 4:  50%|█████     | 44/88 [00:03<00:03, 12.72it/s, training_loss=0.225]
# Epoch 4:  50%|█████     | 44/88 [00:03<00:03, 12.72it/s, training_loss=0.224]
# Epoch 4:  52%|█████▏    | 46/88 [00:03<00:03, 12.69it/s, training_loss=0.224]
# Epoch 4:  52%|█████▏    | 46/88 [00:03<00:03, 12.69it/s, training_loss=0.232]
# Epoch 4:  52%|█████▏    | 46/88 [00:03<00:03, 12.69it/s, training_loss=0.274]
# Epoch 4:  55%|█████▍    | 48/88 [00:03<00:03, 12.63it/s, training_loss=0.274]
# Epoch 4:  55%|█████▍    | 48/88 [00:03<00:03, 12.63it/s, training_loss=0.236]
# Epoch 4:  55%|█████▍    | 48/88 [00:03<00:03, 12.63it/s, training_loss=0.258]
# Epoch 4:  57%|█████▋    | 50/88 [00:03<00:03, 12.65it/s, training_loss=0.258]
# Epoch 4:  57%|█████▋    | 50/88 [00:04<00:03, 12.65it/s, training_loss=0.238]
# Epoch 4:  57%|█████▋    | 50/88 [00:04<00:03, 12.65it/s, training_loss=0.249]
# Epoch 4:  59%|█████▉    | 52/88 [00:04<00:02, 12.60it/s, training_loss=0.249]
# Epoch 4:  59%|█████▉    | 52/88 [00:04<00:02, 12.60it/s, training_loss=0.261]
# Epoch 4:  59%|█████▉    | 52/88 [00:04<00:02, 12.60it/s, training_loss=0.206]
# Epoch 4:  61%|██████▏   | 54/88 [00:04<00:02, 12.56it/s, training_loss=0.206]
# Epoch 4:  61%|██████▏   | 54/88 [00:04<00:02, 12.56it/s, training_loss=0.232]
# Epoch 4:  61%|██████▏   | 54/88 [00:04<00:02, 12.56it/s, training_loss=0.211]
# Epoch 4:  64%|██████▎   | 56/88 [00:04<00:02, 12.58it/s, training_loss=0.211]
# Epoch 4:  64%|██████▎   | 56/88 [00:04<00:02, 12.58it/s, training_loss=0.222]
# Epoch 4:  64%|██████▎   | 56/88 [00:04<00:02, 12.58it/s, training_loss=0.265]
# Epoch 4:  66%|██████▌   | 58/88 [00:04<00:02, 12.58it/s, training_loss=0.265]
# Epoch 4:  66%|██████▌   | 58/88 [00:04<00:02, 12.58it/s, training_loss=0.275]
# Epoch 4:  66%|██████▌   | 58/88 [00:04<00:02, 12.58it/s, training_loss=0.253]
# Epoch 4:  68%|██████▊   | 60/88 [00:04<00:02, 12.55it/s, training_loss=0.253]
# Epoch 4:  68%|██████▊   | 60/88 [00:04<00:02, 12.55it/s, training_loss=0.297]
# Epoch 4:  68%|██████▊   | 60/88 [00:04<00:02, 12.55it/s, training_loss=0.235]
# Epoch 4:  70%|███████   | 62/88 [00:04<00:02, 12.48it/s, training_loss=0.235]
# Epoch 4:  70%|███████   | 62/88 [00:05<00:02, 12.48it/s, training_loss=0.259]
# Epoch 4:  70%|███████   | 62/88 [00:05<00:02, 12.48it/s, training_loss=0.229]
# Epoch 4:  73%|███████▎  | 64/88 [00:05<00:01, 12.43it/s, training_loss=0.229]
# Epoch 4:  73%|███████▎  | 64/88 [00:05<00:01, 12.43it/s, training_loss=0.200]
# Epoch 4:  73%|███████▎  | 64/88 [00:05<00:01, 12.43it/s, training_loss=0.232]
# Epoch 4:  75%|███████▌  | 66/88 [00:05<00:01, 12.39it/s, training_loss=0.232]
# Epoch 4:  75%|███████▌  | 66/88 [00:05<00:01, 12.39it/s, training_loss=0.233]
# Epoch 4:  75%|███████▌  | 66/88 [00:05<00:01, 12.39it/s, training_loss=0.228]
# Epoch 4:  77%|███████▋  | 68/88 [00:05<00:01, 12.37it/s, training_loss=0.228]
# Epoch 4:  77%|███████▋  | 68/88 [00:05<00:01, 12.37it/s, training_loss=0.211]
# Epoch 4:  77%|███████▋  | 68/88 [00:05<00:01, 12.37it/s, training_loss=0.197]
# Epoch 4:  80%|███████▉  | 70/88 [00:05<00:01, 12.36it/s, training_loss=0.197]
# Epoch 4:  80%|███████▉  | 70/88 [00:05<00:01, 12.36it/s, training_loss=0.196]
# Epoch 4:  80%|███████▉  | 70/88 [00:05<00:01, 12.36it/s, training_loss=0.241]
# Epoch 4:  82%|████████▏ | 72/88 [00:05<00:01, 12.37it/s, training_loss=0.241]
# Epoch 4:  82%|████████▏ | 72/88 [00:05<00:01, 12.37it/s, training_loss=0.199]
# Epoch 4:  82%|████████▏ | 72/88 [00:05<00:01, 12.37it/s, training_loss=0.226]
# Epoch 4:  84%|████████▍ | 74/88 [00:05<00:01, 12.35it/s, training_loss=0.226]
# Epoch 4:  84%|████████▍ | 74/88 [00:05<00:01, 12.35it/s, training_loss=0.279]
# Epoch 4:  84%|████████▍ | 74/88 [00:06<00:01, 12.35it/s, training_loss=0.242]
# Epoch 4:  86%|████████▋ | 76/88 [00:06<00:00, 12.34it/s, training_loss=0.242]
# Epoch 4:  86%|████████▋ | 76/88 [00:06<00:00, 12.34it/s, training_loss=0.243]
# Epoch 4:  86%|████████▋ | 76/88 [00:06<00:00, 12.34it/s, training_loss=0.244]
# Epoch 4:  89%|████████▊ | 78/88 [00:06<00:00, 12.30it/s, training_loss=0.244]
# Epoch 4:  89%|████████▊ | 78/88 [00:06<00:00, 12.30it/s, training_loss=0.237]
# Epoch 4:  89%|████████▊ | 78/88 [00:06<00:00, 12.30it/s, training_loss=0.261]
# Epoch 4:  91%|█████████ | 80/88 [00:06<00:00, 12.30it/s, training_loss=0.261]
# Epoch 4:  91%|█████████ | 80/88 [00:06<00:00, 12.30it/s, training_loss=0.232]
# Epoch 4:  91%|█████████ | 80/88 [00:06<00:00, 12.30it/s, training_loss=0.264]
# Epoch 4:  93%|█████████▎| 82/88 [00:06<00:00, 12.32it/s, training_loss=0.264]
# Epoch 4:  93%|█████████▎| 82/88 [00:06<00:00, 12.32it/s, training_loss=0.293]
# Epoch 4:  93%|█████████▎| 82/88 [00:06<00:00, 12.32it/s, training_loss=0.231]
# Epoch 4:  95%|█████████▌| 84/88 [00:06<00:00, 12.34it/s, training_loss=0.231]
# Epoch 4:  95%|█████████▌| 84/88 [00:06<00:00, 12.34it/s, training_loss=0.292]
# Epoch 4:  95%|█████████▌| 84/88 [00:06<00:00, 12.34it/s, training_loss=0.235]
# Epoch 4:  98%|█████████▊| 86/88 [00:06<00:00, 12.37it/s, training_loss=0.235]
# Epoch 4:  98%|█████████▊| 86/88 [00:06<00:00, 12.37it/s, training_loss=0.275]
# Epoch 4:  98%|█████████▊| 86/88 [00:07<00:00, 12.37it/s, training_loss=0.149]
# Epoch 4: 100%|██████████| 88/88 [00:07<00:00, 12.44it/s, training_loss=0.149]
#  40%|████      | 4/10 [00:30<00:45,  7.59s/it]
# Epoch 4
# Training loss: 0.7108092721212994
# Epoch 5:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 5:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.234]
# Epoch 5:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.239]
# Epoch 5:   2%|▏         | 2/88 [00:00<00:06, 12.35it/s, training_loss=0.239]
# Epoch 5:   2%|▏         | 2/88 [00:00<00:06, 12.35it/s, training_loss=0.259]
# Epoch 5:   2%|▏         | 2/88 [00:00<00:06, 12.35it/s, training_loss=0.222]
# Epoch 5:   5%|▍         | 4/88 [00:00<00:06, 12.41it/s, training_loss=0.222]
# Epoch 5:   5%|▍         | 4/88 [00:00<00:06, 12.41it/s, training_loss=0.254]
# Epoch 5:   5%|▍         | 4/88 [00:00<00:06, 12.41it/s, training_loss=0.215]
# Epoch 5:   7%|▋         | 6/88 [00:00<00:06, 12.39it/s, training_loss=0.215]
# Epoch 5:   7%|▋         | 6/88 [00:00<00:06, 12.39it/s, training_loss=0.229]
# Epoch 5:   7%|▋         | 6/88 [00:00<00:06, 12.39it/s, training_loss=0.220]
# Epoch 5:   9%|▉         | 8/88 [00:00<00:06, 12.41it/s, training_loss=0.220]
# Epoch 5:   9%|▉         | 8/88 [00:00<00:06, 12.41it/s, training_loss=0.250]
# Epoch 5:   9%|▉         | 8/88 [00:00<00:06, 12.41it/s, training_loss=0.205]
# Epoch 5:  11%|█▏        | 10/88 [00:00<00:06, 12.39it/s, training_loss=0.205]
# Epoch 5:  11%|█▏        | 10/88 [00:00<00:06, 12.39it/s, training_loss=0.280]
# Epoch 5:  11%|█▏        | 10/88 [00:00<00:06, 12.39it/s, training_loss=0.221]
# Epoch 5:  14%|█▎        | 12/88 [00:00<00:06, 12.36it/s, training_loss=0.221]
# Epoch 5:  14%|█▎        | 12/88 [00:01<00:06, 12.36it/s, training_loss=0.214]
# Epoch 5:  14%|█▎        | 12/88 [00:01<00:06, 12.36it/s, training_loss=0.257]
# Epoch 5:  39%|███▊      | 34/88 [00:02<00:04, 12.41it/s, training_loss=0.233]
# Epoch 5:  41%|████      | 36/88 [00:02<00:04, 12.40it/s, training_loss=0.233]
# Epoch 5:  41%|████      | 36/88 [00:02<00:04, 12.40it/s, training_loss=0.231]
# Epoch 5:  41%|████      | 36/88 [00:03<00:04, 12.40it/s, training_loss=0.207]
# Epoch 5:  43%|████▎     | 38/88 [00:03<00:04, 12.43it/s, training_loss=0.207]
# Epoch 5:  43%|████▎     | 38/88 [00:03<00:04, 12.43it/s, training_loss=0.235]
# Epoch 5:  43%|████▎     | 38/88 [00:03<00:04, 12.43it/s, training_loss=0.225]
# Epoch 5:  45%|████▌     | 40/88 [00:03<00:03, 12.44it/s, training_loss=0.225]
# Epoch 5:  45%|████▌     | 40/88 [00:03<00:03, 12.44it/s, training_loss=0.217]
# Epoch 5:  45%|████▌     | 40/88 [00:03<00:03, 12.44it/s, training_loss=0.236]
# Epoch 5:  48%|████▊     | 42/88 [00:03<00:03, 12.43it/s, training_loss=0.236]
# Epoch 5:  48%|████▊     | 42/88 [00:03<00:03, 12.43it/s, training_loss=0.258]
# Epoch 5:  48%|████▊     | 42/88 [00:03<00:03, 12.43it/s, training_loss=0.214]
# Epoch 5:  50%|█████     | 44/88 [00:03<00:03, 12.42it/s, training_loss=0.214]
# Epoch 5:  50%|█████     | 44/88 [00:03<00:03, 12.42it/s, training_loss=0.242]
# Epoch 5:  50%|█████     | 44/88 [00:03<00:03, 12.42it/s, training_loss=0.230]
# Epoch 5:  52%|█████▏    | 46/88 [00:03<00:03, 12.42it/s, training_loss=0.230]
# Epoch 5:  52%|█████▏    | 46/88 [00:03<00:03, 12.42it/s, training_loss=0.214]
# Epoch 5:  52%|█████▏    | 46/88 [00:03<00:03, 12.42it/s, training_loss=0.243]
# Epoch 5:  55%|█████▍    | 48/88 [00:03<00:03, 12.41it/s, training_loss=0.243]
# Epoch 5:  55%|█████▍    | 48/88 [00:03<00:03, 12.41it/s, training_loss=0.296]
# Epoch 5:  55%|█████▍    | 48/88 [00:04<00:03, 12.41it/s, training_loss=0.213]
# Epoch 5:  57%|█████▋    | 50/88 [00:04<00:03, 12.39it/s, training_loss=0.213]
# Epoch 5:  57%|█████▋    | 50/88 [00:04<00:03, 12.39it/s, training_loss=0.219]
# Epoch 5:  57%|█████▋    | 50/88 [00:04<00:03, 12.39it/s, training_loss=0.248]
# Epoch 5:  59%|█████▉    | 52/88 [00:04<00:02, 12.38it/s, training_loss=0.248]
# Epoch 5:  59%|█████▉    | 52/88 [00:04<00:02, 12.38it/s, training_loss=0.245]
# Epoch 5:  59%|█████▉    | 52/88 [00:04<00:02, 12.38it/s, training_loss=0.230]
# Epoch 5:  61%|██████▏   | 54/88 [00:04<00:02, 12.36it/s, training_loss=0.230]
# ...
# Epoch 9:  48%|████▊     | 42/88 [00:03<00:03, 12.30it/s, training_loss=0.223]
# Epoch 9:  50%|█████     | 44/88 [00:03<00:03, 12.31it/s, training_loss=0.223]
# Epoch 9:  50%|█████     | 44/88 [00:03<00:03, 12.31it/s, training_loss=0.230]
# Epoch 9:  50%|█████     | 44/88 [00:03<00:03, 12.31it/s, training_loss=0.204]
# Epoch 9:  52%|█████▏    | 46/88 [00:03<00:03, 12.36it/s, training_loss=0.204]
# Epoch 9:  52%|█████▏    | 46/88 [00:03<00:03, 12.36it/s, training_loss=0.230]
# Epoch 9:  52%|█████▏    | 46/88 [00:03<00:03, 12.36it/s, training_loss=0.245]
# Epoch 9:  55%|█████▍    | 48/88 [00:03<00:03, 12.37it/s, training_loss=0.245]
# Epoch 9:  55%|█████▍    | 48/88 [00:03<00:03, 12.37it/s, training_loss=0.235]
# Epoch 9:  55%|█████▍    | 48/88 [00:04<00:03, 12.37it/s, training_loss=0.259]
# Epoch 9:  57%|█████▋    | 50/88 [00:04<00:03, 12.42it/s, training_loss=0.259]
# Epoch 9:  57%|█████▋    | 50/88 [00:04<00:03, 12.42it/s, training_loss=0.239]
# Epoch 9:  57%|█████▋    | 50/88 [00:04<00:03, 12.42it/s, training_loss=0.206]
# Epoch 9:  59%|█████▉    | 52/88 [00:04<00:02, 12.36it/s, training_loss=0.206]
# Epoch 9:  59%|█████▉    | 52/88 [00:04<00:02, 12.36it/s, training_loss=0.256]
# Epoch 9:  59%|█████▉    | 52/88 [00:04<00:02, 12.36it/s, training_loss=0.287]
# Epoch 9:  61%|██████▏   | 54/88 [00:04<00:02, 12.36it/s, training_loss=0.287]
# Epoch 9:  61%|██████▏   | 54/88 [00:04<00:02, 12.36it/s, training_loss=0.251]
# Epoch 9:  61%|██████▏   | 54/88 [00:04<00:02, 12.36it/s, training_loss=0.223]
# Epoch 9:  64%|██████▎   | 56/88 [00:04<00:02, 12.35it/s, training_loss=0.223]
# Epoch 9:  64%|██████▎   | 56/88 [00:04<00:02, 12.35it/s, training_loss=0.239]
# Epoch 9:  64%|██████▎   | 56/88 [00:04<00:02, 12.35it/s, training_loss=0.221]
# Epoch 9:  66%|██████▌   | 58/88 [00:04<00:02, 12.34it/s, training_loss=0.221]
# Epoch 9:  66%|██████▌   | 58/88 [00:04<00:02, 12.34it/s, training_loss=0.254]
# Epoch 9:  66%|██████▌   | 58/88 [00:04<00:02, 12.34it/s, training_loss=0.224]
# Epoch 9:  68%|██████▊   | 60/88 [00:04<00:02, 12.33it/s, training_loss=0.224]
# Epoch 9:  68%|██████▊   | 60/88 [00:04<00:02, 12.33it/s, training_loss=0.247]
# Epoch 9:  68%|██████▊   | 60/88 [00:05<00:02, 12.33it/s, training_loss=0.223]
# Epoch 9:  70%|███████   | 62/88 [00:05<00:02, 12.37it/s, training_loss=0.223]
# Epoch 9:  70%|███████   | 62/88 [00:05<00:02, 12.37it/s, training_loss=0.279]
# Epoch 9:  70%|███████   | 62/88 [00:05<00:02, 12.37it/s, training_loss=0.245]
# Epoch 9:  73%|███████▎  | 64/88 [00:05<00:01, 12.36it/s, training_loss=0.245]
# Epoch 9:  73%|███████▎  | 64/88 [00:05<00:01, 12.36it/s, training_loss=0.266]
# Epoch 9:  73%|███████▎  | 64/88 [00:05<00:01, 12.36it/s, training_loss=0.213]
# Epoch 9:  75%|███████▌  | 66/88 [00:05<00:01, 12.38it/s, training_loss=0.213]
# Epoch 9:  75%|███████▌  | 66/88 [00:05<00:01, 12.38it/s, training_loss=0.220]
# Epoch 9:  75%|███████▌  | 66/88 [00:05<00:01, 12.38it/s, training_loss=0.247]
# Epoch 9:  77%|███████▋  | 68/88 [00:05<00:01, 12.39it/s, training_loss=0.247]
# Epoch 9:  77%|███████▋  | 68/88 [00:05<00:01, 12.39it/s, training_loss=0.238]
# Epoch 9:  77%|███████▋  | 68/88 [00:05<00:01, 12.39it/s, training_loss=0.234]
# Epoch 9:  80%|███████▉  | 70/88 [00:05<00:01, 12.40it/s, training_loss=0.234]
# Epoch 9:  80%|███████▉  | 70/88 [00:05<00:01, 12.40it/s, training_loss=0.242]
# Epoch 9:  80%|███████▉  | 70/88 [00:05<00:01, 12.40it/s, training_loss=0.246]
# Epoch 9:  82%|████████▏ | 72/88 [00:05<00:01, 12.39it/s, training_loss=0.246]
# Epoch 9:  82%|████████▏ | 72/88 [00:05<00:01, 12.39it/s, training_loss=0.296]
# Epoch 9:  82%|████████▏ | 72/88 [00:05<00:01, 12.39it/s, training_loss=0.234]
# Epoch 9:  84%|████████▍ | 74/88 [00:05<00:01, 12.40it/s, training_loss=0.234]
# Epoch 9:  84%|████████▍ | 74/88 [00:06<00:01, 12.40it/s, training_loss=0.240]
# Epoch 9:  84%|████████▍ | 74/88 [00:06<00:01, 12.40it/s, training_loss=0.235]
# Epoch 9:  86%|████████▋ | 76/88 [00:06<00:00, 12.42it/s, training_loss=0.235]
# Epoch 9:  86%|████████▋ | 76/88 [00:06<00:00, 12.42it/s, training_loss=0.283]
# Epoch 9:  86%|████████▋ | 76/88 [00:06<00:00, 12.42it/s, training_loss=0.211]
# Epoch 9:  89%|████████▊ | 78/88 [00:06<00:00, 12.40it/s, training_loss=0.211]
# Epoch 9:  89%|████████▊ | 78/88 [00:06<00:00, 12.40it/s, training_loss=0.254]
# Epoch 9:  89%|████████▊ | 78/88 [00:06<00:00, 12.40it/s, training_loss=0.233]
# Epoch 9:  91%|█████████ | 80/88 [00:06<00:00, 12.41it/s, training_loss=0.233]
# Epoch 9:  91%|█████████ | 80/88 [00:06<00:00, 12.41it/s, training_loss=0.205]
# Epoch 9:  91%|█████████ | 80/88 [00:06<00:00, 12.41it/s, training_loss=0.280]
# Epoch 9:  93%|█████████▎| 82/88 [00:06<00:00, 12.43it/s, training_loss=0.280]
# Epoch 9:  93%|█████████▎| 82/88 [00:06<00:00, 12.43it/s, training_loss=0.237]
# Epoch 9:  93%|█████████▎| 82/88 [00:06<00:00, 12.43it/s, training_loss=0.248]
# Epoch 9:  95%|█████████▌| 84/88 [00:06<00:00, 12.44it/s, training_loss=0.248]
# Epoch 9:  95%|█████████▌| 84/88 [00:06<00:00, 12.44it/s, training_loss=0.252]
# Epoch 9:  95%|█████████▌| 84/88 [00:06<00:00, 12.44it/s, training_loss=0.257]
# Epoch 9:  98%|█████████▊| 86/88 [00:06<00:00, 12.46it/s, training_loss=0.257]
# Epoch 9:  98%|█████████▊| 86/88 [00:07<00:00, 12.46it/s, training_loss=0.226]
# Epoch 9:  98%|█████████▊| 86/88 [00:07<00:00, 12.46it/s, training_loss=0.197]
# Epoch 9: 100%|██████████| 88/88 [00:07<00:00, 12.50it/s, training_loss=0.197]
#  90%|█████████ | 9/10 [01:08<00:07,  7.58s/it]
# Epoch 9
# Training loss: 0.7103574540127408
# Epoch 10:   0%|          | 0/88 [00:00<?, ?it/s]
# Epoch 10:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.225]
# Epoch 10:   0%|          | 0/88 [00:00<?, ?it/s, training_loss=0.241]
# Epoch 10:   2%|▏         | 2/88 [00:00<00:06, 12.59it/s, training_loss=0.241]
# Epoch 10:   2%|▏         | 2/88 [00:00<00:06, 12.59it/s, training_loss=0.236]
# Epoch 10:   2%|▏         | 2/88 [00:00<00:06, 12.59it/s, training_loss=0.249]
# Epoch 10:   5%|▍         | 4/88 [00:00<00:06, 12.42it/s, training_loss=0.249]
# Epoch 10:   5%|▍         | 4/88 [00:00<00:06, 12.42it/s, training_loss=0.236]
# Epoch 10:   5%|▍         | 4/88 [00:00<00:06, 12.42it/s, training_loss=0.237]
# Epoch 10:   7%|▋         | 6/88 [00:00<00:06, 12.42it/s, training_loss=0.237]
# Epoch 10:   7%|▋         | 6/88 [00:00<00:06, 12.42it/s, training_loss=0.230]
# Epoch 10:   7%|▋         | 6/88 [00:00<00:06, 12.42it/s, training_loss=0.222]
# Epoch 10:   9%|▉         | 8/88 [00:00<00:06, 12.43it/s, training_loss=0.222]
# Epoch 10:   9%|▉         | 8/88 [00:00<00:06, 12.43it/s, training_loss=0.222]
# Epoch 10:   9%|▉         | 8/88 [00:00<00:06, 12.43it/s, training_loss=0.244]
# Epoch 10:  11%|█▏        | 10/88 [00:00<00:06, 12.44it/s, training_loss=0.244]
# Epoch 10:  11%|█▏        | 10/88 [00:00<00:06, 12.44it/s, training_loss=0.231]
# Epoch 10:  11%|█▏        | 10/88 [00:00<00:06, 12.44it/s, training_loss=0.223]
# Epoch 10:  14%|█▎        | 12/88 [00:00<00:06, 12.44it/s, training_loss=0.223]
# Epoch 10:  14%|█▎        | 12/88 [00:01<00:06, 12.44it/s, training_loss=0.230]
# Epoch 10:  14%|█▎        | 12/88 [00:01<00:06, 12.44it/s, training_loss=0.219]
# Epoch 10:  16%|█▌        | 14/88 [00:01<00:05, 12.43it/s, training_loss=0.219]
# Epoch 10:  16%|█▌        | 14/88 [00:01<00:05, 12.43it/s, training_loss=0.253]
# Epoch 10:  16%|█▌        | 14/88 [00:01<00:05, 12.43it/s, training_loss=0.229]
# Epoch 10:  18%|█▊        | 16/88 [00:01<00:05, 12.43it/s, training_loss=0.229]
# Epoch 10:  18%|█▊        | 16/88 [00:01<00:05, 12.43it/s, training_loss=0.244]
# Epoch 10:  18%|█▊        | 16/88 [00:01<00:05, 12.43it/s, training_loss=0.279]
# Epoch 10:  43%|████▎     | 38/88 [00:03<00:04, 12.27it/s, training_loss=0.223]
# Epoch 10:  43%|████▎     | 38/88 [00:03<00:04, 12.27it/s, training_loss=0.240]
# Epoch 10:  45%|████▌     | 40/88 [00:03<00:03, 12.38it/s, training_loss=0.240]
# Epoch 10:  45%|████▌     | 40/88 [00:03<00:03, 12.38it/s, training_loss=0.250]
# Epoch 10:  45%|████▌     | 40/88 [00:03<00:03, 12.38it/s, training_loss=0.245]
# Epoch 10:  48%|████▊     | 42/88 [00:03<00:03, 12.46it/s, training_loss=0.245]
# Epoch 10:  48%|████▊     | 42/88 [00:03<00:03, 12.46it/s, training_loss=0.254]
# Epoch 10:  48%|████▊     | 42/88 [00:03<00:03, 12.46it/s, training_loss=0.244]
# Epoch 10:  50%|█████     | 44/88 [00:03<00:03, 12.54it/s, training_loss=0.244]
# Epoch 10:  50%|█████     | 44/88 [00:03<00:03, 12.54it/s, training_loss=0.255]
# Epoch 10:  50%|█████     | 44/88 [00:03<00:03, 12.54it/s, training_loss=0.233]
# Epoch 10:  52%|█████▏    | 46/88 [00:03<00:03, 12.59it/s, training_loss=0.233]
# Epoch 10:  52%|█████▏    | 46/88 [00:03<00:03, 12.59it/s, training_loss=0.205]
# Epoch 10:  52%|█████▏    | 46/88 [00:03<00:03, 12.59it/s, training_loss=0.205]
# Epoch 10:  55%|█████▍    | 48/88 [00:03<00:03, 12.60it/s, training_loss=0.205]
# Epoch 10:  55%|█████▍    | 48/88 [00:03<00:03, 12.60it/s, training_loss=0.247]
# Epoch 10:  55%|█████▍    | 48/88 [00:04<00:03, 12.60it/s, training_loss=0.230]
# Epoch 10:  57%|█████▋    | 50/88 [00:04<00:03, 12.48it/s, training_loss=0.230]
# Epoch 10:  57%|█████▋    | 50/88 [00:04<00:03, 12.48it/s, training_loss=0.218]
# Epoch 10:  57%|█████▋    | 50/88 [00:04<00:03, 12.48it/s, training_loss=0.278]
# Epoch 10:  59%|█████▉    | 52/88 [00:04<00:02, 12.51it/s, training_loss=0.278]
# Epoch 10:  59%|█████▉    | 52/88 [00:04<00:02, 12.51it/s, training_loss=0.241]
# Epoch 10:  59%|█████▉    | 52/88 [00:04<00:02, 12.51it/s, training_loss=0.234]
# Epoch 10:  61%|██████▏   | 54/88 [00:04<00:02, 12.56it/s, training_loss=0.234]
# Epoch 10:  61%|██████▏   | 54/88 [00:04<00:02, 12.56it/s, training_loss=0.273]
# Epoch 10:  61%|██████▏   | 54/88 [00:04<00:02, 12.56it/s, training_loss=0.190]
# Epoch 10:  64%|██████▎   | 56/88 [00:04<00:02, 12.57it/s, training_loss=0.190]
# Epoch 10:  64%|██████▎   | 56/88 [00:04<00:02, 12.57it/s, training_loss=0.207]
# Epoch 10:  64%|██████▎   | 56/88 [00:04<00:02, 12.57it/s, training_loss=0.227]
# Epoch 10:  66%|██████▌   | 58/88 [00:04<00:02, 12.54it/s, training_loss=0.227]
# Epoch 10:  66%|██████▌   | 58/88 [00:04<00:02, 12.54it/s, training_loss=0.231]
# Epoch 10:  66%|██████▌   | 58/88 [00:04<00:02, 12.54it/s, training_loss=0.232]
# Epoch 10:  68%|██████▊   | 60/88 [00:04<00:02, 12.57it/s, training_loss=0.232]
# Epoch 10:  68%|██████▊   | 60/88 [00:04<00:02, 12.57it/s, training_loss=0.223]
# Epoch 10:  68%|██████▊   | 60/88 [00:04<00:02, 12.57it/s, training_loss=0.249]
# Epoch 10:  70%|███████   | 62/88 [00:04<00:02, 12.63it/s, training_loss=0.249]
# Epoch 10:  70%|███████   | 62/88 [00:05<00:02, 12.63it/s, training_loss=0.183]
# Epoch 10:  70%|███████   | 62/88 [00:05<00:02, 12.63it/s, training_loss=0.234]
# Epoch 10:  73%|███████▎  | 64/88 [00:05<00:01, 12.59it/s, training_loss=0.234]
# Epoch 10:  73%|███████▎  | 64/88 [00:05<00:01, 12.59it/s, training_loss=0.267]
# Epoch 10:  73%|███████▎  | 64/88 [00:05<00:01, 12.59it/s, training_loss=0.238]
# Epoch 10:  75%|███████▌  | 66/88 [00:05<00:01, 12.59it/s, training_loss=0.238]
# Epoch 10:  75%|███████▌  | 66/88 [00:05<00:01, 12.59it/s, training_loss=0.226]
# Epoch 10:  75%|███████▌  | 66/88 [00:05<00:01, 12.59it/s, training_loss=0.220]
# Epoch 10:  77%|███████▋  | 68/88 [00:05<00:01, 12.63it/s, training_loss=0.220]
# Epoch 10:  77%|███████▋  | 68/88 [00:05<00:01, 12.63it/s, training_loss=0.194]
# Epoch 10:  77%|███████▋  | 68/88 [00:05<00:01, 12.63it/s, training_loss=0.256]
# Epoch 10:  80%|███████▉  | 70/88 [00:05<00:01, 12.59it/s, training_loss=0.256]
# Epoch 10:  80%|███████▉  | 70/88 [00:05<00:01, 12.59it/s, training_loss=0.239]
# Epoch 10:  80%|███████▉  | 70/88 [00:05<00:01, 12.59it/s, training_loss=0.194]
# Epoch 10:  82%|████████▏ | 72/88 [00:05<00:01, 12.58it/s, training_loss=0.194]
# Epoch 10:  82%|████████▏ | 72/88 [00:05<00:01, 12.58it/s, training_loss=0.238]
# Epoch 10:  82%|████████▏ | 72/88 [00:05<00:01, 12.58it/s, training_loss=0.233]
# Epoch 10:  84%|████████▍ | 74/88 [00:05<00:01, 12.54it/s, training_loss=0.233]
# Epoch 10:  84%|████████▍ | 74/88 [00:05<00:01, 12.54it/s, training_loss=0.250]
# Epoch 10:  84%|████████▍ | 74/88 [00:06<00:01, 12.54it/s, training_loss=0.287]
# Epoch 10:  86%|████████▋ | 76/88 [00:06<00:00, 12.59it/s, training_loss=0.287]
# Epoch 10:  86%|████████▋ | 76/88 [00:06<00:00, 12.59it/s, training_loss=0.199]
# Epoch 10:  86%|████████▋ | 76/88 [00:06<00:00, 12.59it/s, training_loss=0.240]
# Epoch 10:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.240]
# Epoch 10:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.251]
# Epoch 10:  89%|████████▊ | 78/88 [00:06<00:00, 12.65it/s, training_loss=0.252]
# Epoch 10:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.252]
# Epoch 10:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.250]
# Epoch 10:  91%|█████████ | 80/88 [00:06<00:00, 12.62it/s, training_loss=0.271]
# Epoch 10:  93%|█████████▎| 82/88 [00:06<00:00, 12.60it/s, training_loss=0.271]
# Epoch 10:  93%|█████████▎| 82/88 [00:06<00:00, 12.60it/s, training_loss=0.213]
# Epoch 10:  93%|█████████▎| 82/88 [00:06<00:00, 12.60it/s, training_loss=0.267]
# Epoch 10:  95%|█████████▌| 84/88 [00:06<00:00, 12.53it/s, training_loss=0.267]
# Epoch 10:  95%|█████████▌| 84/88 [00:06<00:00, 12.53it/s, training_loss=0.195]
# Epoch 10:  95%|█████████▌| 84/88 [00:06<00:00, 12.53it/s, training_loss=0.191]
# Epoch 10:  98%|█████████▊| 86/88 [00:06<00:00, 12.54it/s, training_loss=0.191]
# Epoch 10:  98%|█████████▊| 86/88 [00:06<00:00, 12.54it/s, training_loss=0.255]
# Epoch 10:  98%|█████████▊| 86/88 [00:07<00:00, 12.54it/s, training_loss=0.211]
# Epoch 10: 100%|██████████| 88/88 [00:07<00:00, 12.66it/s, training_loss=0.211]
# 100%|██████████| 10/10 [01:15<00:00,  7.56s/it]
# Epoch 10
# Training loss: 0.7077298868786205

# %%
##Optional, when I am uploading th emodel
model = BertForSequenceClassification.from_pretrained("allenai/scibert_scivocab_uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)

model.to(device)

model.load_state_dict(torch.load('/content/finetuned_SciBERT_epoch_10.model', map_location=torch.device('cpu')))
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: allenai/scibert_scivocab_uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.seq_relationship.weight                | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.seq_relationship.bias                  | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# classifier.weight                          | MISSING    |
# classifier.bias                            | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# <All keys matched successfully>

# %%
_, predictions, true_vals = evaluate(dataloader_validation)

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.51      0.86      0.64        88
#            1       0.56      0.17      0.26        87
#
#     accuracy                           0.52       175
#    macro avg       0.53      0.52      0.45       175
# weighted avg       0.53      0.52      0.45       175
#
# Overall accuracy: 0.52
# F1 macro       : 0.4536128456735058

# %%
predictions[:3]
# Out:
# array([[ 0.22120705, -0.09085   ],
#        [ 0.16976723, -0.10131858],
#        [ 0.37934768,  0.00634021]], dtype=float32)
